# %%
import time
import re

import pandas as pd
from collections import OrderedDict

import json
import os

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
from deck_crawler.parse_deck import parse_events_from_official
from deck_crawler.parse_deck import reassign_category

# %%
# flags
RUN_PARSE = True
DEBUG_PARSE = True

NUM_RESULT_PAGE = 2
NUM_EVENT_PAGE = 50
NUM_DECK_PAGE = 2

# %%
# create some folders
EXCEL_FOLDER = "excel"
DB_FOLDER = "deck_db"
LOG_FOLDER = "logs"
folders = [EXCEL_FOLDER, DB_FOLDER, LOG_FOLDER]
for folder in folders:
    if not os.path.exists(folder):
        os.makedirs(folder)

# %%
# loading
decks = {}
store_file_name = 'deck_db/store.json'
if not DEBUG_PARSE:
    store_file_name = 'deck_db/test.json'
    if os.path.exists(store_file_name):
        with open(store_file_name, 'r') as f:
            decks = json.load(f)

decks = reassign_category(decks)
print("categories in previous result:")
print(decks.keys())

store_code_list = []
for category in decks.keys():
    for d in decks[category]:
        store_code_list.append(d["deck_code"])
print('\n')
print("number of decks in the previous result:")
print(len(store_code_list))
# Out:
# categories in previous result:
# dict_keys([])
#
#
# number of decks in the previous result:
# 0

# %%
# parse events
t1 = time.time()
if RUN_PARSE or DEBUG_PARSE:
    parse_events_from_official(
        decks,
        store_code_list,
        result_page_limit=NUM_RESULT_PAGE,
        event_page_limit=NUM_EVENT_PAGE,
        deck_page_limit=NUM_DECK_PAGE
    )
t2 = time.time()

print()
print(f"{t2 - t1} seconds")
# Out:
# Processing result page: 0: 100%|██████████| 20/20 [03:56<00:00, 11.81s/it]
# Processing result page: 1: 100%|██████████| 20/20 [03:03<00:00,  9.17s/it]
#
# 426.4015920162201 seconds

# %%
# save to json
with open(store_file_name, 'w') as f:
    json.dump(decks, f, ensure_ascii=False, indent=4)

# %%
# show all categories we have
total = 0
for k in decks.keys():
    print(f"[{k}]:\n{len(decks[k])}\n")
    total += len(decks[k])

print(total)
# Out:
# [ルギアVSTAR]:
# 98
#
# [アル_ジュラルドン]:
# 37
#
# [ミュウVMAX]:
# 37
#
# [LTB_カイオーガ]:
# 8
#
# [ムゲンダイナVMAX]:
# 22
#
# [Other_Lost]:
# 13
#
# [ヒスイ ダイケンキVSTAR]:
# 1
#
# [LOST_ギラティナVSTAR]:
# 18
#
# [アル_そらをとぶピカチュウ]:
# 34
#
# [レジ]:
# 21
#
# [ハピナスV]:
# 6
#
# [オリジンパルキアVSTAR]:
# 10
#
# [アル_レジドラゴVSTAR]:
# 2
#
# [LTB]:
# 9
#
# [ゾロア_ウインディ]:
# 2
#
# [キュレムVMAX]:
# 13
#
# [ガラル マタドガス]:
# 4
#
# [others]:
# 19
#
# [レジエレキVMAX]:
# 7
#
# [LTB_ヤミラミ_リザードン]:
# 10
#
# [ヒスイ ゾロアークVSTAR]:
# 5
#
# [LTB_空の封印石_水草超闘雷]:
# 1
#
# [こくばバドレックスVMAX]:
# 2
#
# [アルセウス裏工作]:
# 4
#
# [LTB_空の封印石_水超鋼闘雷]:
# 2
#
# [LTB_空の封印石_水超鋼雷]:
# 7
#
# [LTB_空の封印石_水超闘雷]:
# 6
#
# [ロトムVSTAR]:
# 1
#
# [LTB_空の封印石_other]:
# 2
#
# [LTB_空の封印石_水超鋼]:
# 2
#
# [ゾロア]:
# 1
#
# [ミュウツーV-UNION]:
# 1
#
# [プテラVSTAR]:
# 1
#
# [オリジンディアルガVSTAR]:
# 4
#
# [LTB_空の封印石_草超鋼雷]:
# 1
#
# [ルナトーン]:
# 2
#
# [LTB_空の封印石_超鋼雷]:
# 1
#
# [Other_ギラティナVSTAR]:
# 1
#
# 415

# %%
start_date = "2022年12月18日"  # include
end_date = "2022年12月31日"  # include

# %%
target_category = "こくばバドレックスVMAX"
number_decks = 0

# show categories we have in the period
for k in decks.keys():
    deck_cnt = 0
    for deck in decks[k]:
        if deck["date"] >= start_date and deck["date"] <= end_date:
            deck_cnt += 1

    print(f"{k}\t{deck_cnt}\n")
    if k == target_category:
        number_decks = deck_cnt
# Out:
# ルギアVSTAR	98
#
# アル_ジュラルドン	37
#
# ミュウVMAX	37
#
# LTB_カイオーガ	8
#
# ムゲンダイナVMAX	22
#
# Other_Lost	13
#
# ヒスイ ダイケンキVSTAR	1
#
# LOST_ギラティナVSTAR	18
#
# アル_そらをとぶピカチュウ	34
#
# レジ	21
#
# ハピナスV	6
#
# オリジンパルキアVSTAR	10
#
# アル_レジドラゴVSTAR	2
#
# LTB	9
#
# ゾロア_ウインディ	2
#
# キュレムVMAX	13
#
# ガラル マタドガス	4
#
# others	19
#
# レジエレキVMAX	7
#
# LTB_ヤミラミ_リザードン	10
#
# ヒスイ ゾロアークVSTAR	5
#
# LTB_空の封印石_水草超闘雷	1
#
# こくばバドレックスVMAX	2
#
# アルセウス裏工作	4
#
# LTB_空の封印石_水超鋼闘雷	2
#
# LTB_空の封印石_水超鋼雷	7
#
# LTB_空の封印石_水超闘雷	6
#
# ロトムVSTAR	1
#
# LTB_空の封印石_other	2
#
# LTB_空の封印石_水超鋼	2
#
# ゾロア	1
#
# ミュウツーV-UNION	1
#
# プテラVSTAR	1
#
# オリジンディアルガVSTAR	4
#
# LTB_空の封印石_草超鋼雷	1
#
# ルナトーン	2
#
# LTB_空の封印石_超鋼雷	1
#
# Other_ギラティナVSTAR	1

# %%
# number of decks for the target category
print(number_decks)
if number_decks <= 0:
    raise Exception(f"No decks for {target_category} during {start_date} to {end_date}")
# Out:
# 2

# %%
# Analysis
df_list = []
common_cols = ["date", "num_players", "rank"]

for card_type in ["pokemons", "tools", "supporters", "stadiums", "energies"]:
    # df init
    df = pd.DataFrame()
    for _, deck in enumerate(decks[target_category]):
        deck_link = deck["deck_link"]  # row id
        if deck["date"] < start_date or deck["date"] > end_date:
            continue
        pokecard = OrderedDict()
        pokecard["date"] = deck["date"]
        pokecard["num_players"] = deck["num_players"]
        pokecard["rank"] = deck["rank"]
        pokecard.update(deck[card_type])
        if _ == 0:
            df = pd.DataFrame(pokecard, index=[deck_link])
        else:
            df = pd.concat([df, pd.DataFrame(pokecard, index=[deck_link])])
    df = df.fillna(0)
    
    # sort rows by date
    df = df.sort_values(by=['date'], ascending=False)

    # select cols for analysis
    col_list = list(df)
    for c in common_cols: col_list.remove(c)

    # calculate
    num_decks = df.shape[0]
    num_used = df[col_list].sum(axis='rows', numeric_only=True)
    num_picked = df[col_list].astype(bool).sum(axis='rows')
    avg_num_used = num_used / num_picked
    pick_rate = num_picked / num_decks
    
    # insert rows in df
    df.loc["avg_num_used"] = {}
    df.loc["pick_rate"] = {}
    for col in col_list:
        df.loc["avg_num_used", col] = avg_num_used[col]
        df.loc["pick_rate", col] = pick_rate[col]

    # reorder index in df, move 'avg_num_used' and 'pick_rate' to top
    num_rows = df.shape[0]
    target_rows = [num_rows-1, num_rows-2]
    idx = target_rows + [i for i in range(len(df)) if i not in target_rows]
    df = df.iloc[idx]
    
    # sort cols by pick rate
    df = df.sort_values('pick_rate', axis=1, ascending=False)
    col_list = list(df)
    for c in common_cols: col_list.remove(c)
    df = df[common_cols + col_list]
    
    # store
    df_list.append(df)

# %%
# excel writer
writer = pd.ExcelWriter(f"{EXCEL_FOLDER}/{target_category}-{start_date}-{end_date}.xlsx", engine='xlsxwriter')
df_list[0].to_excel(writer, sheet_name='pokemons')
df_list[1].to_excel(writer, sheet_name='tools')
df_list[2].to_excel(writer, sheet_name='supporters')
df_list[3].to_excel(writer, sheet_name='stadiums')
df_list[4].to_excel(writer, sheet_name='energies')
writer.save()

# %%
df_list[0]
# Out:
#                                                                                       date  \
# pick_rate                                                                              NaN
# avg_num_used                                                                           NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng  2022年12月29日(木)
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv  2022年12月28日(水)
#
#                                                                             num_players  \
# pick_rate                                                                           NaN
# avg_num_used                                                                        NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng         32.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv         64.0
#
#                                                                             rank  \
# pick_rate                                                                    NaN
# avg_num_used                                                                 NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng   5.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv   5.0
#
#                                                                             エーフィVMAX  \
# pick_rate                                                                        1.0
# avg_num_used                                                                     1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng       1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv       1.0
#
#                                                                             エーフィV  \
# pick_rate                                                                     1.0
# avg_num_used                                                                  1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng    1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv    1.0
#
#                                                                             こくばバドレックスVMAX  \
# pick_rate                                                                             1.0
# avg_num_used                                                                          4.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng            4.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv            4.0
#
#                                                                             こくばバドレックスV  \
# pick_rate                                                                          1.0
# avg_num_used                                                                       3.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng         2.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv         4.0
#
#                                                                             クロバットV  \
# pick_rate                                                                      1.0
# avg_num_used                                                                   1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng     1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv     1.0
#
#                                                                             ネオラントV  \
# pick_rate                                                                      1.0
# avg_num_used                                                                   1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng     1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv     1.0
#
#                                                                             マホイップVMAX  \
# pick_rate                                                                         0.5
# avg_num_used                                                                      1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng        1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv        0.0
#
#                                                                             マホイップV  \
# pick_rate                                                                      0.5
# avg_num_used                                                                   1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng     1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv     0.0
#
#                                                                             ガラル フリーザー  \
# pick_rate                                                                         0.5
# avg_num_used                                                                      1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng        1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv        0.0
#
#                                                                             かがやくムゲンダイナ  \
# pick_rate                                                                          0.5
# avg_num_used                                                                       1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng         1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv         0.0
#
#                                                                             メタモンV  \
# pick_rate                                                                     0.5
# avg_num_used                                                                  1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng    1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv    0.0
#
#                                                                             アルセウスV  \
# pick_rate                                                                      0.5
# avg_num_used                                                                   2.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng     0.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv     2.0
#
#                                                                             アルセウスVSTAR
# pick_rate                                                                          0.5
# avg_num_used                                                                       2.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng         0.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv         2.0

# %%
df_list[1]
# Out:
#                                                                                       date  \
# pick_rate                                                                              NaN
# avg_num_used                                                                           NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng  2022年12月29日(木)
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv  2022年12月28日(水)
#
#                                                                             num_players  \
# pick_rate                                                                           NaN
# avg_num_used                                                                        NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng         32.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv         64.0
#
#                                                                             rank  \
# pick_rate                                                                    NaN
# avg_num_used                                                                 NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng   5.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv   5.0
#
#                                                                             霧の水晶  \
# pick_rate                                                                    1.0
# avg_num_used                                                                 3.5
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng   4.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv   3.0
#
#                                                                             ふうせん  \
# pick_rate                                                                    1.0
# avg_num_used                                                                 1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng   1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv   1.0
#
#                                                                             ハイパーボール  \
# pick_rate                                                                       1.0
# avg_num_used                                                                    2.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng      2.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv      2.0
#
#                                                                             ポケモンいれかえ  \
# pick_rate                                                                        1.0
# avg_num_used                                                                     1.5
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng       2.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv       1.0
#
#                                                                             エネルギー回収  \
# pick_rate                                                                       1.0
# avg_num_used                                                                    1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng      1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv      1.0
#
#                                                                             クイックボール  \
# pick_rate                                                                       1.0
# avg_num_used                                                                    3.5
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng      4.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv      3.0
#
#                                                                             こだわりベルト  \
# pick_rate                                                                       1.0
# avg_num_used                                                                    1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng      1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv      1.0
#
#                                                                             エネルギーつけかえ  \
# pick_rate                                                                         0.5
# avg_num_used                                                                      1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng        0.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv        1.0
#
#                                                                             しんかのおこう  \
# pick_rate                                                                       0.5
# avg_num_used                                                                    1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng      0.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv      1.0
#
#                                                                             バトルVIPパス  \
# pick_rate                                                                        0.5
# avg_num_used                                                                     4.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng       0.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv       4.0
#
#                                                                             回収ネット  \
# pick_rate                                                                     0.5
# avg_num_used                                                                  1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng    1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv    0.0
#
#                                                                             森の封印石  \
# pick_rate                                                                     0.5
# avg_num_used                                                                  1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng    1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv    0.0
#
#                                                                             ロストスイーパー  \
# pick_rate                                                                        0.5
# avg_num_used                                                                     1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng       1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv       0.0
#
#                                                                             やまびこホーン  \
# pick_rate                                                                       0.5
# avg_num_used                                                                    1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng      1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv      0.0
#
#                                                                             ふつうのつりざお  \
# pick_rate                                                                        0.5
# avg_num_used                                                                     1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng       1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv       0.0
#
#                                                                             ヒスイのヘビーボール  \
# pick_rate                                                                          0.5
# avg_num_used                                                                       1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng         1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv         0.0
#
#                                                                             あなぬけのヒモ
# pick_rate                                                                       0.5
# avg_num_used                                                                    1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng      0.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv      1.0

# %%
df_list[2]
# Out:
#                                                                                       date  \
# pick_rate                                                                              NaN
# avg_num_used                                                                           NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng  2022年12月29日(木)
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv  2022年12月28日(水)
#
#                                                                             num_players  \
# pick_rate                                                                           NaN
# avg_num_used                                                                        NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng         32.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv         64.0
#
#                                                                             rank  \
# pick_rate                                                                    NaN
# avg_num_used                                                                 NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng   5.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv   5.0
#
#                                                                             博士の研究  \
# pick_rate                                                                     1.0
# avg_num_used                                                                  1.5
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng    1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv    2.0
#
#                                                                             マリィ  \
# pick_rate                                                                   1.0
# avg_num_used                                                                2.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng  2.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv  2.0
#
#                                                                             セレナ  \
# pick_rate                                                                   1.0
# avg_num_used                                                                2.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng  2.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv  2.0
#
#                                                                             ツツジ  \
# pick_rate                                                                   1.0
# avg_num_used                                                                1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng  1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv  1.0
#
#                                                                             ボスの指令  \
# pick_rate                                                                     1.0
# avg_num_used                                                                  1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng    1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv    1.0
#
#                                                                             ネジキ
# pick_rate                                                                   0.5
# avg_num_used                                                                1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng  1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv  0.0

# %%
df_list[3]
# Out:
#                                                                                       date  \
# pick_rate                                                                              NaN
# avg_num_used                                                                           NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng  2022年12月29日(木)
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv  2022年12月28日(水)
#
#                                                                             num_players  \
# pick_rate                                                                           NaN
# avg_num_used                                                                        NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng         32.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv         64.0
#
#                                                                             rank  \
# pick_rate                                                                    NaN
# avg_num_used                                                                 NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng   5.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv   5.0
#
#                                                                             シンオウ神殿
# pick_rate                                                                      1.0
# avg_num_used                                                                   2.5
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng     2.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv     3.0

# %%
df_list[4]
# Out:
#                                                                                       date  \
# pick_rate                                                                              NaN
# avg_num_used                                                                           NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng  2022年12月29日(木)
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv  2022年12月28日(水)
#
#                                                                             num_players  \
# pick_rate                                                                           NaN
# avg_num_used                                                                        NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng         32.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv         64.0
#
#                                                                             rank  \
# pick_rate                                                                    NaN
# avg_num_used                                                                 NaN
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng   5.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv   5.0
#
#                                                                             基本超エネルギー  \
# pick_rate                                                                        1.0
# avg_num_used                                                                    13.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng      13.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv      13.0
#
#                                                                             ダブルターボエネルギー
# pick_rate                                                                           0.5
# avg_num_used                                                                        1.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/HnngPL-j61c5o-LNnnng          0.0
# https://www.pokemon-card.com/deck/confirm.html/deckID/fkf1kF-0G0Smz-VFkkVv          1.0

# %%
decks["others"]
# Out:
# [{'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/XyMy2y-gwZ51h-yRUMyy',
#   'deck_code': 'XyMy2y-gwZ51h-yRUMyy',
#   'pokemons': {'ポワルン あまみずのすがた': 3,
#    'ライコウV': 2,
#    'エモンガ': 1,
#    'ドラピオンV': 1,
#    'スターミーV': 1,
#    'ガラル サンダーV': 1,
#    'ネオラントV': 1,
#    'かがやくゲッコウガ': 1},
#   'tools': {'クイックボール': 4,
#    'バトルVIPパス': 4,
#    'ヒスイのヘビーボール': 1,
#    'エネルギー転送': 3,
#    'クロススイッチャー': 4,
#    'あなぬけのヒモ': 2,
#    '回収ネット': 3,
#    'トレッキングシューズ': 3,
#    '森の封印石': 2,
#    '空の封印石': 1,
#    'ともだちてちょう': 1,
#    'ふつうのつりざお': 1},
#   'supporters': {'メロン': 4},
#   'stadiums': {'ポケストップ': 3},
#   'energies': {'スピード雷エネルギー': 3, '基本雷エネルギー': 2, '基本水エネルギー': 6, '基本闘エネルギー': 2},
#   'rank': 9,
#   'num_players': 70,
#   'date': '2022年12月29日(木)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/8ax444-0wttB9-48xJ88',
#   'deck_code': '8ax444-0wttB9-48xJ88',
#   'pokemons': {'インテレオン': 3,
#    'ジメレオン': 4,
#    'メッソン': 4,
#    'マナフィ': 1,
#    'かがやくリザードン': 1,
#    'ライコウV': 1,
#    'ガラル サンダーV': 1,
#    'ドラピオンV': 1},
#   'tools': {'レベルボール': 4,
#    'クイックボール': 3,
#    'ヒスイのヘビーボール': 1,
#    'しんかのおこう': 3,
#    'ふしぎなアメ': 2,
#    'エネルギー転送': 3,
#    'ふつうのつりざお': 1,
#    '回収ネット': 3,
#    'クロススイッチャー': 2,
#    'あなぬけのヒモ': 1,
#    '空の封印石': 2,
#    'こだわりベルト': 1,
#    'ビッグパラソル': 1},
#   'supporters': {'カイ': 3, 'キバナ': 3, 'クララ': 1},
#   'stadiums': {'トレーニングコート': 1, 'シンオウ神殿': 1},
#   'energies': {'基本水エネルギー': 2,
#    '基本雷エネルギー': 2,
#    '基本炎エネルギー': 1,
#    '基本闘エネルギー': 1,
#    'ツインエネルギー': 1},
#   'rank': 9,
#   'num_players': 48,
#   'date': '2022年12月29日(木)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/pMypyy-egU9OJ-y3Sppy',
#   'deck_code': 'pMypyy-egU9OJ-y3Sppy',
#   'pokemons': {'ドラパルトVMAX': 3,
#    'ドラパルトV': 3,
#    'アップリュー': 1,
#    'タルップル': 1,
#    'カジッチュ': 3,
#    'ザシアンV': 1,
#    'クロバットV': 2,
#    'マナフィ': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'レベルボール': 2,
#    '霧の水晶': 4,
#    'レスキューキャリー': 1,
#    'ポケモンいれかえ': 1,
#    'あなぬけのヒモ': 1,
#    'ともだちてちょう': 1,
#    'やまびこホーン': 1,
#    'ツールスクラッパー': 1,
#    'こだわりベルト': 2,
#    'ふうせん': 1,
#    '森の封印石': 2},
#   'supporters': {'博士の研究': 4, 'マリィ': 1, 'ボスの指令': 1, 'セレナ': 1, 'キバナ': 1},
#   'stadiums': {'シンオウ神殿': 3},
#   'energies': {'基本超エネルギー': 7},
#   'rank': 9,
#   'num_players': 48,
#   'date': '2022年12月29日(木)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/8D8a8x-Kgw0Or-8K88xY',
#   'deck_code': '8D8a8x-Kgw0Or-8K88xY',
#   'pokemons': {'カラマネロV': 3,
#    'カラマネロVMAX': 2,
#    'アルセウスV': 4,
#    'アルセウスVSTAR': 2,
#    'クロバットV': 1,
#    'ネオラントV': 1,
#    'ヨマワル': 2,
#    'ヨノワール': 2,
#    'バケッチャ': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'しんかのおこう': 2,
#    'あなぬけのヒモ': 2,
#    'ふつうのつりざお': 1,
#    'ふしぎなアメ': 3},
#   'supporters': {'マリィ': 3, '博士の研究': 3, 'セレナ': 1, 'キバナ': 2, 'ツツジ': 2},
#   'stadiums': {'頂への雪道': 3},
#   'energies': {'基本悪エネルギー': 7, 'ダブルターボエネルギー': 3, 'キャプチャーエネルギー': 2},
#   'rank': 9,
#   'num_players': 72,
#   'date': '2022年12月29日(木)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/84DJD8-W7K4UL-x8cxx8',
#   'deck_code': '84DJD8-W7K4UL-x8cxx8',
#   'pokemons': {'クワガノンV': 2,
#    'ライコウV': 1,
#    'ガラル ファイヤーV': 2,
#    'ガラル サンダーV': 1,
#    'クロバットV': 2,
#    'メタモンV': 1,
#    'かがやくゲッコウガ': 1,
#    'サンダー': 2},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 3,
#    'ヒスイのヘビーボール': 1,
#    'あなぬけのヒモ': 2,
#    'いれかえカート': 2,
#    'ロストスイーパー': 1,
#    'ふうせん': 2,
#    'おはらいグローブ': 1,
#    'こだわりベルト': 1,
#    'タフネスマント': 1,
#    '森の封印石': 1,
#    '空の封印石': 1,
#    'エネルギーつけかえ': 4,
#    'エネルギー転送': 2},
#   'supporters': {'キバナ': 2, 'マリィ': 2, 'ボスの指令': 2, 'アクロマの実験': 3, 'セレナ': 1},
#   'stadiums': {'ロストシティ': 1, 'ガラル鉱山': 1},
#   'energies': {'基本悪エネルギー': 4, 'オーロラエネルギー': 4, '基本闘エネルギー': 1, '基本雷エネルギー': 1},
#   'rank': 5,
#   'num_players': 64,
#   'date': '2022年12月28日(水)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/G88x48-6RkPJx-848DJD',
#   'deck_code': 'G88x48-6RkPJx-848DJD',
#   'pokemons': {'アーケオス': 3,
#    'クイタラン': 2,
#    'オムスターV': 2,
#    'アーケン': 3,
#    'ライコウV': 1,
#    'エンテイV': 1,
#    'ヤレユータン': 1,
#    'ネオラントV': 1,
#    'クロバットV': 1,
#    'ルージュラ': 1,
#    'ミルタンク': 1,
#    'マフォクシーV': 1,
#    'かがやくリザードン': 1},
#   'tools': {'ヒスイのヘビーボール': 1,
#    'ハイパーボール': 2,
#    'クイックボール': 4,
#    'しんかのおこう': 2,
#    '森の封印石': 2,
#    'こだわりベルト': 1,
#    'タフネスマント': 1,
#    'ポケモンいれかえ': 1,
#    'あなぬけのヒモ': 1},
#   'supporters': {'ハマナのバックアップ': 1,
#    'カイ': 2,
#    'ボスの指令': 2,
#    'マリィ': 2,
#    'ツツジ': 1,
#    '博士の研究': 1,
#    'セレナ': 1},
#   'stadiums': {'頂への雪道': 1, '崩れたスタジアム': 1},
#   'energies': {'ダブルターボエネルギー': 2,
#    'Vガードエネルギー': 1,
#    'ヒート炎エネルギー': 4,
#    'ツインエネルギー': 3,
#    'オーロラエネルギー': 4},
#   'rank': 9,
#   'num_players': 64,
#   'date': '2022年12月28日(水)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/kVf1kv-qYy7E4-kk5Fkk',
#   'deck_code': 'kVf1kv-qYy7E4-kk5Fkk',
#   'pokemons': {'アイアント': 3,
#    'チラーミィ': 3,
#    'チラチーノ': 3,
#    'ミルタンク': 1,
#    'マナフィ': 1,
#    'イベルタル': 2,
#    'モルペコ': 1,
#    'コオリッポ': 2,
#    'カビゴン': 1,
#    'メタモン': 1},
#   'tools': {'クイックボール': 4,
#    'レベルボール': 3,
#    '回収ネット': 4,
#    'やまびこホーン': 1,
#    'レスキューキャリー': 3,
#    'ヒスイのヘビーボール': 1,
#    'ふつうのつりざお': 1,
#    'エネくじ': 1},
#   'supporters': {'ボスの指令': 4, 'シバ': 2, 'マリィ': 3, 'セレナ': 2},
#   'stadiums': {'ガラル鉱山': 4},
#   'energies': {'ウォッシュ水エネルギー': 2, 'ツインエネルギー': 3, 'ダブルターボエネルギー': 4},
#   'rank': 3,
#   'num_players': 96,
#   'date': '2022年12月28日(水)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/aKx488-FPzvUJ-cxJ888',
#   'deck_code': 'aKx488-FPzvUJ-cxJ888',
#   'pokemons': {'カビゴン': 3,
#    'メタモン': 2,
#    'ミルタンク': 1,
#    'イベルタル': 2,
#    'メグロコ': 1,
#    'ヨクバリスV': 1,
#    'ピジョットV': 1,
#    'ワタシラガV': 1,
#    'レジエレキ': 1,
#    'コオリッポ': 1,
#    'ナマコブシ': 1,
#    'マナフィ': 1,
#    'ルージュラ': 1,
#    'かがやくサーナイト': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 1,
#    'ヒスイのヘビーボール': 1,
#    'トレッキングシューズ': 4,
#    '回収ネット': 2,
#    'タフネスマント': 2,
#    'しあわせタマゴ': 1,
#    '森の封印石': 1,
#    'ロストスイーパー': 1,
#    'レスキューキャリー': 1,
#    'ともだちてちょう': 1},
#   'supporters': {'シマボシ': 1,
#    'シバ': 1,
#    'アスナ': 1,
#    'カゲツ': 1,
#    'シャクヤ': 1,
#    'チェレンの気くばり': 1,
#    'とりつかい': 2,
#    'セレナ': 1,
#    'アクロマの実験': 3,
#    '博士の研究': 1},
#   'stadiums': {'ガラル鉱山': 2},
#   'energies': {'ダブルターボエネルギー': 4, 'ツインエネルギー': 3, 'ウォッシュ水エネルギー': 1},
#   'rank': 5,
#   'num_players': 96,
#   'date': '2022年12月28日(水)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/yUMyMy-hj8u6T-RyMpyS',
#   'deck_code': 'yUMyMy-hj8u6T-RyMpyS',
#   'pokemons': {'アルセウスVSTAR': 3,
#    'アルセウスV': 4,
#    'カラマネロVMAX': 2,
#    'カラマネロV': 2,
#    'クロバットV': 1,
#    'かがやくサーナイト': 1},
#   'tools': {'クイックボール': 3,
#    'ハイパーボール': 4,
#    'しんかのおこう': 2,
#    'ポケモンいれかえ': 2,
#    'ビッグパラソル': 2,
#    'クラッシュハンマー': 4},
#   'supporters': {'マリィ': 4, '博士の研究': 2, 'ツツジ': 2, 'ボスの指令': 3, 'セレナ': 1},
#   'stadiums': {'頂への雪道': 3, 'ロストシティ': 2},
#   'energies': {'ダブルターボエネルギー': 4, 'Vガードエネルギー': 2, '基本悪エネルギー': 7},
#   'rank': 9,
#   'num_players': 96,
#   'date': '2022年12月28日(水)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/ypyypy-IyJbRd-MXy2ES',
#   'deck_code': 'ypyypy-IyJbRd-MXy2ES',
#   'pokemons': {'ガラル タチフサグマ': 1,
#    'ガラル マッスグマ': 1,
#    'ガラル ジグザグマ': 3,
#    'イベルタル': 1,
#    'インテレオン': 2,
#    'ジメレオン': 3,
#    'メッソン': 4,
#    'マナフィ': 1,
#    'かがやくリザードン': 1,
#    'カビゴン': 1},
#   'tools': {'レベルボール': 4,
#    'クイックボール': 3,
#    'ハイパーボール': 2,
#    'ヒスイのヘビーボール': 1,
#    'しんかのおこう': 1,
#    'エネルギー転送': 1,
#    'ふしぎなアメ': 4,
#    '回収ネット': 4,
#    'ダークパッチ': 1,
#    'ふつうのつりざお': 1,
#    'ビッグパラソル': 1},
#   'supporters': {'シロナの覇気': 1,
#    'マリィ': 1,
#    'カイ': 1,
#    'キバナ': 1,
#    'クララ': 1,
#    'ネズ': 1,
#    'ボスの指令': 1},
#   'stadiums': {'シンオウ神殿': 1},
#   'energies': {'基本悪エネルギー': 5, '基本炎エネルギー': 1, 'オーロラエネルギー': 1, 'ツインエネルギー': 1},
#   'rank': 5,
#   'num_players': 64,
#   'date': '2022年12月27日(火)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/nPnQQL-3BcVHX-nNnnNL',
#   'deck_code': 'nPnQQL-3BcVHX-nNnnNL',
#   'pokemons': {'ダークライV': 4,
#    'ダークライVSTAR': 3,
#    'ガラル ファイヤーV': 2,
#    'クロバットV': 1,
#    'かがやくゲッコウガ': 1,
#    'ガラル ファイヤー': 1},
#   'tools': {'クイックボール': 3,
#    'ハイパーボール': 4,
#    'ダークパッチ': 4,
#    'ポケモンいれかえ': 2,
#    'ふつうのつりざお': 1,
#    'トレッキングシューズ': 3,
#    'こだわりベルト': 2,
#    'ヒスイのヘビーボール': 1,
#    'バトルVIPパス': 2},
#   'supporters': {'博士の研究': 4, 'キバナ': 1, 'セレナ': 3, 'ツツジ': 1},
#   'stadiums': {'シンオウ神殿': 3},
#   'energies': {'基本悪エネルギー': 14},
#   'rank': 9,
#   'num_players': 48,
#   'date': '2022年12月26日(月)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/kbV5kk-E2z9SX-vkVvkV',
#   'deck_code': 'kbV5kk-E2z9SX-vkVvkV',
#   'pokemons': {'ウッウ': 3, 'サシカマス': 4, 'ミルタンク': 2, 'かがやくジラーチ': 1},
#   'tools': {'クイックボール': 4,
#    'バトルVIPパス': 4,
#    'ヒスイのヘビーボール': 2,
#    'レスキューキャリー': 4,
#    'トレッキングシューズ': 4,
#    'ウッウロボ': 3,
#    'あなぬけのヒモ': 2,
#    '回収ネット': 2,
#    'タフネスマント': 2},
#   'supporters': {'博士の研究': 4, 'ルリナ': 3, 'マリィ': 3, 'セレナ': 2},
#   'stadiums': {'頂への雪道': 3},
#   'energies': {'ツインエネルギー': 4, 'ダブルターボエネルギー': 4},
#   'rank': 9,
#   'num_players': 100,
#   'date': '2022年12月26日(月)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/kkvVVw-dqAMRE-kk5kV5',
#   'deck_code': 'kkvVVw-dqAMRE-kk5kV5',
#   'pokemons': {'ヒスイ ドレディアVSTAR': 2,
#    'ヒスイ ドレディアV': 2,
#    'ドダイトス': 3,
#    'ハヤシガメ': 4,
#    'ナエトル': 4,
#    'ゴリランダー': 2,
#    'バチンキー': 1,
#    'サルノリ': 2,
#    'アゲハント': 1,
#    'カラサリス': 1,
#    'ケムッソ': 1,
#    'スピアー': 1,
#    'ゲンガー': 1},
#   'tools': {'バトルVIPパス': 4,
#    'ふしぎなアメ': 3,
#    'ふつうのつりざお': 3,
#    'あなぬけのヒモ': 2,
#    'こだわりベルト': 2,
#    'ハイパーボール': 1},
#   'supporters': {'ピオニー': 4, 'オニオン': 2, 'とりつかい': 1, 'マリィ': 1, 'キバナ': 1},
#   'stadiums': {'ターフスタジアム': 3},
#   'energies': {'キャプチャーエネルギー': 2, '基本草エネルギー': 6},
#   'rank': 9,
#   'num_players': 64,
#   'date': '2022年12月25日(日)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/5Fkfkk-oFrbHl-kkk5VF',
#   'deck_code': '5Fkfkk-oFrbHl-kkk5VF',
#   'pokemons': {'かがやくリザードン': 1,
#    'インテレオン': 2,
#    'ジメレオン': 3,
#    'メッソン': 4,
#    'マナフィ': 1,
#    'ミュウ': 1,
#    'カビゴン': 1,
#    'コオリッポ': 1,
#    'ミルタンク': 1,
#    'ドラピオンV': 1},
#   'tools': {'クイックボール': 3,
#    'レベルボール': 4,
#    'しんかのおこう': 3,
#    'ヒスイのヘビーボール': 1,
#    '回収ネット': 4,
#    'エネルギー転送': 3,
#    'こだわりベルト': 2,
#    'ビッグパラソル': 1,
#    'ふつうのつりざお': 1,
#    'やまびこホーン': 1,
#    'クロススイッチャー': 4},
#   'supporters': {'カイ': 4, 'キバナ': 2, 'クララ': 2, 'ボスの指令': 1},
#   'stadiums': {'マグマの滝壺': 2},
#   'energies': {'基本炎エネルギー': 2, '基本水エネルギー': 2, 'ツインエネルギー': 2},
#   'rank': 9,
#   'num_players': 64,
#   'date': '2022年12月25日(日)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/nn6LNn-zvc7Sh-NngnPg',
#   'deck_code': 'nn6LNn-zvc7Sh-NngnPg',
#   'pokemons': {'オムスターV': 3,
#    'かがやくジラーチ': 1,
#    'エイパム': 3,
#    'エテボース': 3,
#    'ミルタンク': 1,
#    'マフォクシーV': 1,
#    'ネオラントV': 1,
#    'アーケン': 3,
#    'アーケオス': 2,
#    'マナフィ': 1},
#   'tools': {'森の封印石': 1,
#    '大地の封印石': 1,
#    'しんかのおこう': 1,
#    'ヒスイのヘビーボール': 1,
#    'ハイパーボール': 2,
#    'ポケモンいれかえ': 1,
#    'クイックボール': 1,
#    'こだわりベルト': 1,
#    'ロストスイーパー': 1,
#    'あなぬけのヒモ': 1,
#    'レベルボール': 1},
#   'supporters': {'セレナ': 2, 'カイ': 2, 'ボスの指令': 1, 'ヒナツ': 1, 'マリィ': 1},
#   'stadiums': {'頂への雪道': 2, 'ルミナスメイズの森': 1},
#   'energies': {'ヒート炎エネルギー': 1,
#    'オーロラエネルギー': 2,
#    'ツインエネルギー': 4,
#    'ダブルターボエネルギー': 4,
#    'パワフル無色エネルギー': 2,
#    'ウォッシュ水エネルギー': 2,
#    'キャプチャーエネルギー': 1,
#    'ギフトエネルギー': 1},
#   'rank': 9,
#   'num_players': 64,
#   'date': '2022年12月25日(日)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/iLLNiL-aoE7mb-nNinnn',
#   'deck_code': 'iLLNiL-aoE7mb-nNinnn',
#   'pokemons': {'アルセウスVSTAR': 3,
#    'アルセウスV': 3,
#    'イベルタル': 4,
#    'カビゴン': 4,
#    'ヤレユータン': 1,
#    'ノコッチ': 1,
#    'かがやくサーナイト': 1,
#    'ドラピオンV': 2},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'ポケモンいれかえ': 1,
#    'あなぬけのヒモ': 1,
#    '回収ネット': 2,
#    '大きなおまもり': 2,
#    'ロストスイーパー': 1},
#   'supporters': {'博士の研究': 3,
#    'マリィ': 2,
#    'ボスの指令': 3,
#    'キバナ': 1,
#    'チェレンの気くばり': 2,
#    'カゲツ': 1,
#    'クララ': 1},
#   'stadiums': {'崩れたスタジアム': 1},
#   'energies': {'ダブルターボエネルギー': 4, 'ツインエネルギー': 2, '基本悪エネルギー': 6},
#   'rank': 2,
#   'num_players': 32,
#   'date': '2022年12月25日(日)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/488x88-GAY35X-8D8c48',
#   'deck_code': '488x88-GAY35X-8D8c48',
#   'pokemons': {'ゼラオラV': 3, 'ゼラオラVMAX': 3, 'アルセウスV': 4, 'アルセウスVSTAR': 3},
#   'tools': {'ハイパーボール': 4,
#    'ポケギア3.0': 3,
#    'キャンセルコロン': 1,
#    'すごいきずぐすり': 2,
#    'ポケモンいれかえ': 2,
#    'クイックボール': 3},
#   'supporters': {'チェレンの気くばり': 2,
#    'ボスの指令': 2,
#    'セレナ': 2,
#    'ジャッジマン': 2,
#    'マリィ': 3,
#    '博士の研究': 4},
#   'stadiums': {'シンオウ神殿': 2, '頂への雪道': 3, 'ロストシティ': 1},
#   'energies': {'基本雷エネルギー': 7, 'ダブルターボエネルギー': 4},
#   'rank': 5,
#   'num_players': 32,
#   'date': '2022年12月25日(日)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/5dbfkk-lOGyZG-kVkkkV',
#   'deck_code': '5dbfkk-lOGyZG-kVkkkV',
#   'pokemons': {'エンテイV': 3,
#    'ライコウV': 1,
#    'チラーミィ': 3,
#    'チラチーノ': 3,
#    'ヤレユータン': 1,
#    'マナフィ': 1,
#    'かがやくリザードン': 1,
#    'ドラピオンV': 1,
#    'クロバットV': 1},
#   'tools': {'クイックボール': 4,
#    'クロススイッチャー': 4,
#    'ポケモンいれかえ': 1,
#    'ハイパーボール': 1,
#    'ふうせん': 1,
#    'あなぬけのヒモ': 1,
#    'ヒスイのヘビーボール': 1,
#    'こだわりベルト': 1,
#    '森の封印石': 1,
#    '空の封印石': 1,
#    'ふつうのつりざお': 1,
#    'やまびこホーン': 1,
#    'タフネスマント': 1},
#   'supporters': {'マリィ': 4, '博士の研究': 1, 'ボスの指令': 2, 'キバナ': 2, 'ツツジ': 1},
#   'stadiums': {'マグマの滝壺': 3},
#   'energies': {'キャプチャーエネルギー': 3, 'ヒート炎エネルギー': 2, '基本雷エネルギー': 1, '基本炎エネルギー': 7},
#   'rank': 5,
#   'num_players': 32,
#   'date': '2022年12月25日(日)'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/8x8x88-g7uvqt-884cDx',
#   'deck_code': '8x8x88-g7uvqt-884cDx',
#   'pokemons': {'ヒスイ ウインディV': 4,
#    'クロバットV': 1,
#    'ガラル サンダー': 3,
#    'ヤレユータン': 1,
#    'かがやくゲッコウガ': 1},
#   'tools': {'クイックボール': 4,
#    'フェザーボール': 2,
#    '回収ネット': 4,
#    'トレッキングシューズ': 4,
#    'ガッツのつるはし': 4,
#    'エネルギー回収': 3,
#    'あなぬけのヒモ': 2,
#    '学習装置': 3,
#    '空の封印石': 1},
#   'supporters': {'博士の研究': 4, 'セレナ': 2, 'ボスの指令': 1},
#   'stadiums': {'シンオウ神殿': 2},
#   'energies': {'基本闘エネルギー': 14},
#   'rank': 9,
#   'num_players': 80,
#   'date': '2022年12月25日(日)'}]

# %%
len(decks["others"])
# Out:
# 19
