# %%
import time
import re

import pandas as pd
from collections import OrderedDict

import json
import os

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# %%
from deck_crawler.parse_deck import parse_events_from_official
from deck_crawler.parse_deck import reassign_category

# %%
# flags and parameters
RUN_PARSE = False
DEBUG_PARSE = False

NUM_RESULT_PAGE = 30
NUM_EVENT_PAGE = 1000
NUM_DECK_PAGE = 2

START_DATE = "2022年12月02日"  # include
END_DATE = "2023年1月04日"  # include

TARGET_CATEGORY = "LTB_カイリュー"

# %%
# create some folders
EXCEL_FOLDER = "excel"
DB_FOLDER = "deck_db"
LOG_FOLDER = "logs"
folders = [EXCEL_FOLDER, DB_FOLDER, LOG_FOLDER]

for folder in folders:
    if not os.path.exists(folder):
        os.makedirs(folder)

if not os.path.exists(f"{EXCEL_FOLDER}/{TARGET_CATEGORY}"):
    os.makedirs(f"{EXCEL_FOLDER}/{TARGET_CATEGORY}")

# %%
# loading db
decks = {}
store_file_name = "deck_db/test.json"
if not DEBUG_PARSE:
    store_file_name = "deck_db/store.json"
    if os.path.exists(store_file_name):
        with open(store_file_name, "r") as f:
            decks = json.load(f)

decks = reassign_category(decks)
print("categories in previous result:")
print(decks.keys())

store_code_list = []
for category in decks.keys():
    for d in decks[category]:
        store_code_list.append(d["deck_code"])
print("\n")
print("number of decks in the previous result:")
print(len(store_code_list))
# Out:
# categories in previous result:
# dict_keys(['ルナトーン', 'アル_ジュラルドン', 'かがやくムゲンダイナ', 'アル_レジドラゴVSTAR', 'Other_ギラティナVSTAR', 'ルギアVSTAR', 'レジエレキVMAX', 'Other_Lost', 'LTB', 'こくばバドレックスVMAX', 'アル_そらをとぶピカチュウ', 'キュレムVMAX', 'クロススイッチャー', 'レジドラゴVSTAR', 'ガラル マタドガス', 'ハピナスV', 'ミュウツーV-UNION', 'オリジンパルキアVSTAR', 'プテラVSTAR', 'LOST_ギラティナVSTAR', 'オリジンディアルガVSTAR', 'LTB_リザードン', 'LTB_ウッウ', 'LTB_ヤミラミ_リザードン', 'LTB_カイオーガ', 'LTB_カイリュー', 'LTB_空の封印石_水超鋼雷', 'LTB_空の封印石_草超鋼雷', 'LTB_空の封印石_水超闘雷', 'LTB_空の封印石_水超雷', 'LTB_空の封印石_水草超雷', 'LTB_空の封印石_水草超闘雷', 'LTB_空の封印石_水超鋼闘雷', 'LTB_空の封印石_other', 'LTB_空の封印石_水超鋼', 'LTB_空の封印石_超鋼雷', 'LTB_空の封印石_水草超', 'LTB_空の封印石_草超闘雷', 'LTB_空の封印石_草超鋼闘雷', 'LTB_空の封印石_水草超鋼雷', 'LTB_空の封印石_水草超鋼闘雷', 'ミュウVMAX', 'ヒスイ ゾロアークVSTAR', 'ムゲンダイナVMAX', 'ゾロア', 'ヒスイ ダイケンキVSTAR', 'アルセウス裏工作', 'レジ', 'others', 'ゾロア_ウインディ', 'ロトムVSTAR'])
#
#
# number of decks in the previous result:
# 4292

# %%
# parse events
t1 = time.time()
if RUN_PARSE or DEBUG_PARSE:
    parse_events_from_official(
        decks,
        store_code_list,
        result_page_limit=NUM_RESULT_PAGE,
        event_page_limit=NUM_EVENT_PAGE,
        deck_page_limit=NUM_DECK_PAGE,
    )
t2 = time.time()

print()
print(f"{t2 - t1} seconds")
# Out:
# 6.604194641113281e-05 seconds

# %%
# save to json
with open(store_file_name, "w") as f:
    json.dump(decks, f, ensure_ascii=False, indent=4)

# %%
# show all categories we have
total = 0
for k in decks.keys():
    print(f"[{k}]:\n{len(decks[k])}\n")
    total += len(decks[k])

print(total)
# Out:
# [ルナトーン]:
# 25
#
# [アル_ジュラルドン]:
# 242
#
# [かがやくムゲンダイナ]:
# 69
#
# [アル_レジドラゴVSTAR]:
# 12
#
# [Other_ギラティナVSTAR]:
# 30
#
# [ルギアVSTAR]:
# 1024
#
# [レジエレキVMAX]:
# 83
#
# [Other_Lost]:
# 73
#
# [LTB]:
# 507
#
# [こくばバドレックスVMAX]:
# 6
#
# [アル_そらをとぶピカチュウ]:
# 130
#
# [キュレムVMAX]:
# 87
#
# [クロススイッチャー]:
# 179
#
# [レジドラゴVSTAR]:
# 7
#
# [ガラル マタドガス]:
# 179
#
# [ハピナスV]:
# 41
#
# [ミュウツーV-UNION]:
# 12
#
# [オリジンパルキアVSTAR]:
# 157
#
# [プテラVSTAR]:
# 17
#
# [LOST_ギラティナVSTAR]:
# 122
#
# [オリジンディアルガVSTAR]:
# 16
#
# [LTB_リザードン]:
# 3
#
# [LTB_ウッウ]:
# 1
#
# [LTB_ヤミラミ_リザードン]:
# 124
#
# [LTB_カイオーガ]:
# 92
#
# [LTB_カイリュー]:
# 11
#
# [LTB_空の封印石_水超鋼雷]:
# 41
#
# [LTB_空の封印石_草超鋼雷]:
# 3
#
# [LTB_空の封印石_水超闘雷]:
# 31
#
# [LTB_空の封印石_水超雷]:
# 5
#
# [LTB_空の封印石_水草超雷]:
# 2
#
# [LTB_空の封印石_水草超闘雷]:
# 1
#
# [LTB_空の封印石_水超鋼闘雷]:
# 3
#
# [LTB_空の封印石_other]:
# 5
#
# [LTB_空の封印石_水超鋼]:
# 3
#
# [LTB_空の封印石_超鋼雷]:
# 5
#
# [LTB_空の封印石_水草超]:
# 1
#
# [LTB_空の封印石_草超闘雷]:
# 1
#
# [LTB_空の封印石_草超鋼闘雷]:
# 1
#
# [LTB_空の封印石_水草超鋼雷]:
# 2
#
# [LTB_空の封印石_水草超鋼闘雷]:
# 1
#
# [ミュウVMAX]:
# 400
#
# [ヒスイ ゾロアークVSTAR]:
# 27
#
# [ムゲンダイナVMAX]:
# 112
#
# [ゾロア]:
# 62
#
# [ヒスイ ダイケンキVSTAR]:
# 8
#
# [アルセウス裏工作]:
# 32
#
# [レジ]:
# 175
#
# [others]:
# 92
#
# [ゾロア_ウインディ]:
# 15
#
# [ロトムVSTAR]:
# 15
#
# 4292

# %%
# show categories we have in the period
number_decks = 0
for k in decks.keys():
    deck_cnt = 0
    for deck in decks[k]:
        if deck["date"] >= START_DATE and deck["date"] <= END_DATE:
            deck_cnt += 1

    print(f"{k}\t{deck_cnt}\n")
    if k == TARGET_CATEGORY:
        number_decks = deck_cnt
# Out:
# ルナトーン	15
#
# アル_ジュラルドン	141
#
# かがやくムゲンダイナ	69
#
# アル_レジドラゴVSTAR	8
#
# Other_ギラティナVSTAR	15
#
# ルギアVSTAR	494
#
# レジエレキVMAX	40
#
# Other_Lost	59
#
# LTB	299
#
# こくばバドレックスVMAX	6
#
# アル_そらをとぶピカチュウ	96
#
# キュレムVMAX	42
#
# クロススイッチャー	89
#
# レジドラゴVSTAR	4
#
# ガラル マタドガス	132
#
# ハピナスV	29
#
# ミュウツーV-UNION	8
#
# オリジンパルキアVSTAR	81
#
# プテラVSTAR	8
#
# LOST_ギラティナVSTAR	68
#
# オリジンディアルガVSTAR	9
#
# LTB_リザードン	0
#
# LTB_ウッウ	0
#
# LTB_ヤミラミ_リザードン	47
#
# LTB_カイオーガ	66
#
# LTB_カイリュー	11
#
# LTB_空の封印石_水超鋼雷	41
#
# LTB_空の封印石_草超鋼雷	3
#
# LTB_空の封印石_水超闘雷	31
#
# LTB_空の封印石_水超雷	5
#
# LTB_空の封印石_水草超雷	2
#
# LTB_空の封印石_水草超闘雷	1
#
# LTB_空の封印石_水超鋼闘雷	3
#
# LTB_空の封印石_other	5
#
# LTB_空の封印石_水超鋼	3
#
# LTB_空の封印石_超鋼雷	5
#
# LTB_空の封印石_水草超	1
#
# LTB_空の封印石_草超闘雷	1
#
# LTB_空の封印石_草超鋼闘雷	1
#
# LTB_空の封印石_水草超鋼雷	2
#
# LTB_空の封印石_水草超鋼闘雷	1
#
# ミュウVMAX	222
#
# ヒスイ ゾロアークVSTAR	15
#
# ムゲンダイナVMAX	84
#
# ゾロア	22
#
# ヒスイ ダイケンキVSTAR	6
#
# アルセウス裏工作	19
#
# レジ	102
#
# others	59
#
# ゾロア_ウインディ	6
#
# ロトムVSTAR	4

# %%
# number of decks for the target category
print(number_decks)
if number_decks <= 0:
    raise Exception(f"No decks for {TARGET_CATEGORY} during {START_DATE} to {END_DATE}")
# Out:
# 11

# %%
# Analysis
df_list = []
common_cols = ["date", "prefecture", "num_players", "rank"]
int_cols = ["num_players", "rank"]

for card_type in ["pokemons", "tools", "supporters", "stadiums", "energies"]:
    # df init
    df = pd.DataFrame()
    for _, deck in enumerate(decks[TARGET_CATEGORY]):
        deck_code = deck["deck_code"]  # row id
        if deck["date"] < START_DATE or deck["date"] > END_DATE:
            continue
        pokecard = OrderedDict()
        for col in common_cols:
            pokecard[col] = deck.get(col, "")
        pokecard.update(deck[card_type])
        if _ == 0:
            df = pd.DataFrame(pokecard, index=[deck_code])
        else:
            df = pd.concat([df, pd.DataFrame(pokecard, index=[deck_code])])
    df = df.fillna(0)

    # sort rows by date
    df = df.sort_values(by=["date"], ascending=False)

    # select cols for analysis
    col_list = list(df)
    for c in common_cols:
        col_list.remove(c)

    # calculate
    num_decks = df.shape[0]
    num_used = df[col_list].sum(axis="rows", numeric_only=True)
    num_picked = df[col_list].astype(bool).sum(axis="rows")
    avg_num_used = num_used / num_picked
    pick_rate = num_picked / num_decks

    # insert rows in df
    df.loc["avg_num_used"] = {}
    df.loc["pick_rate"] = {}
    for col in col_list:
        df.loc["avg_num_used", col] = avg_num_used[col]
        df.loc["pick_rate", col] = pick_rate[col]

    # reorder index in df, move 'avg_num_used' and 'pick_rate' to top
    num_rows = df.shape[0]
    target_rows = [num_rows - 1, num_rows - 2]
    idx = target_rows + [i for i in range(len(df)) if i not in target_rows]
    df = df.iloc[idx]

    # sort cols by pick rate
    df = df.sort_values("pick_rate", axis=1, ascending=False)
    col_list = list(df)
    for c in common_cols:
        col_list.remove(c)
    df = df[common_cols + col_list]

    # format data type
    for col in int_cols:
        df[col] = df[col].astype("Int64")

    # store
    df_list.append(df)

# %%
# excel writer
writer = pd.ExcelWriter(
    f"{EXCEL_FOLDER}/{TARGET_CATEGORY}/{TARGET_CATEGORY}-{START_DATE}-{END_DATE}.xlsx",
    engine="xlsxwriter",
    mode="w",
)
workbook = writer.book

for sheet_id, sheet_name in enumerate(
    ["pokemons", "tools", "supporters", "stadiums", "energies"]
):
    df_list[sheet_id].to_excel(writer, sheet_name=sheet_name, float_format="%.2f")

    # Make deck_link become a hyperlink
    # Get the xlsxwriter workbook and worksheet objects
    worksheet = writer.sheets[sheet_name]
    for i, deck_id in enumerate(df_list[sheet_id].index):
        if deck_id in ["avg_num_used", "pick_rate"]:
            continue

        # Calculate the row number
        row = i + 2

        # Write the hyperlink to the cell
        worksheet.write_url(
            f"A{row}",
            f"https://www.pokemon-card.com/deck/confirm.html/deckID/{deck_id}",
            string=f"{deck_id}",
        )

    # formatting
    header_format = workbook.add_format(
        {"bold": True, "text_wrap": True, "valign": "top"}
    )
    for col_num, value in enumerate(df_list[sheet_id].columns.values):
        worksheet.write(0, col_num + 1, value, header_format)
    worksheet.autofit()

workbook.close()
writer.save()

# %%
df_list[0]
# Out:
#                                 date prefecture  num_players  rank  \
# pick_rate                        NaN        NaN         <NA>  <NA>
# avg_num_used                     NaN        NaN         <NA>  <NA>
# pSypy2-7wzfiA-pyXRXM  2023年01月04日(水)        奈良県           96    10
# Y48ccY-vlgUnf-KYxxDx  2023年01月02日(月)        東京都           32     3
# dvvwkk-PURvbj-kkFVkv  2022年12月30日(金)        群馬県           32     2
# yySSXM-6Ii86T-yyyER3  2022年12月30日(金)        東京都           64     6
# 1kVfkV-EP6eYK-kkkVfk  2022年12月29日(木)        埼玉県           70    10
# JKc8cx-o2eLmv-888D4c  2022年12月29日(木)       鹿児島県           48    12
# iNnngn-A0P52C-ngnnLL  2022年12月28日(水)         京都           32     6
# kkkVVk-9cCUy3-FFvkFv  2022年12月25日(日)        大阪府           32     3
# 4xx88D-w4lMzg-DcY8x8  2022年12月23日(金)        大阪府          100     5
# nLngLQ-Wn9DHf-9nnQLn  2022年12月22日(木)        東京都           70    11
# xD8Kx8-r0a1o0-Gxcc8J  2022年12月18日(日)        宮崎県           64    10
#
#                       ヤミラミ\nS11 044/100  カイリューV\nS7R 042/067  \
# pick_rate                           1.0             0.909091
# avg_num_used                        1.0             1.000000
# pSypy2-7wzfiA-pyXRXM                1.0             1.000000
# Y48ccY-vlgUnf-KYxxDx                1.0             1.000000
# dvvwkk-PURvbj-kkFVkv                1.0             1.000000
# yySSXM-6Ii86T-yyyER3                1.0             1.000000
# 1kVfkV-EP6eYK-kkkVfk                1.0             1.000000
# JKc8cx-o2eLmv-888D4c                1.0             1.000000
# iNnngn-A0P52C-ngnnLL                1.0             1.000000
# kkkVVk-9cCUy3-FFvkFv                1.0             1.000000
# 4xx88D-w4lMzg-DcY8x8                1.0             1.000000
# nLngLQ-Wn9DHf-9nnQLn                1.0             0.000000
# xD8Kx8-r0a1o0-Gxcc8J                1.0             1.000000
#
#                       キュワワー\nS11 049/100  カイオーガ\nS8a 007/028  \
# pick_rate                       0.818182            0.727273
# avg_num_used                    4.000000            1.000000
# pSypy2-7wzfiA-pyXRXM            4.000000            1.000000
# Y48ccY-vlgUnf-KYxxDx            4.000000            1.000000
# dvvwkk-PURvbj-kkFVkv            4.000000            1.000000
# yySSXM-6Ii86T-yyyER3            4.000000            0.000000
# 1kVfkV-EP6eYK-kkkVfk            4.000000            1.000000
# JKc8cx-o2eLmv-888D4c            0.000000            1.000000
# iNnngn-A0P52C-ngnnLL            4.000000            1.000000
# kkkVVk-9cCUy3-FFvkFv            4.000000            1.000000
# 4xx88D-w4lMzg-DcY8x8            4.000000            1.000000
# nLngLQ-Wn9DHf-9nnQLn            0.000000            0.000000
# xD8Kx8-r0a1o0-Gxcc8J            4.000000            0.000000
#
#                       ライコウV\nS12a 038/172  かがやくゲッコウガ\nS12a 033/172  \
# pick_rate                        0.545455                 0.545455
# avg_num_used                     1.000000                 1.000000
# pSypy2-7wzfiA-pyXRXM             0.000000                 1.000000
# Y48ccY-vlgUnf-KYxxDx             0.000000                 0.000000
# dvvwkk-PURvbj-kkFVkv             1.000000                 0.000000
# yySSXM-6Ii86T-yyyER3             1.000000                 1.000000
# 1kVfkV-EP6eYK-kkkVfk             1.000000                 0.000000
# JKc8cx-o2eLmv-888D4c             1.000000                 1.000000
# iNnngn-A0P52C-ngnnLL             0.000000                 1.000000
# kkkVVk-9cCUy3-FFvkFv             1.000000                 0.000000
# 4xx88D-w4lMzg-DcY8x8             0.000000                 1.000000
# nLngLQ-Wn9DHf-9nnQLn             0.000000                 1.000000
# xD8Kx8-r0a1o0-Gxcc8J             1.000000                 0.000000
#
#                       かがやくゲッコウガ\nS9a 026/067  ライコウV\nSI 137/414  \
# pick_rate                           0.454545           0.454545
# avg_num_used                        1.000000           1.000000
# pSypy2-7wzfiA-pyXRXM                0.000000           1.000000
# Y48ccY-vlgUnf-KYxxDx                1.000000           1.000000
# dvvwkk-PURvbj-kkFVkv                1.000000           0.000000
# yySSXM-6Ii86T-yyyER3                0.000000           0.000000
# 1kVfkV-EP6eYK-kkkVfk                1.000000           0.000000
# JKc8cx-o2eLmv-888D4c                0.000000           0.000000
# iNnngn-A0P52C-ngnnLL                0.000000           1.000000
# kkkVVk-9cCUy3-FFvkFv                1.000000           0.000000
# 4xx88D-w4lMzg-DcY8x8                0.000000           1.000000
# nLngLQ-Wn9DHf-9nnQLn                0.000000           1.000000
# xD8Kx8-r0a1o0-Gxcc8J                1.000000           0.000000
#
#                       ネオラントV\nSPD 002/020  ドラピオンV\nS12a 085/172  \
# pick_rate                        0.363636              0.272727
# avg_num_used                     1.000000              1.000000
# pSypy2-7wzfiA-pyXRXM             0.000000              0.000000
# Y48ccY-vlgUnf-KYxxDx             0.000000              0.000000
# dvvwkk-PURvbj-kkFVkv             1.000000              0.000000
# yySSXM-6Ii86T-yyyER3             1.000000              1.000000
# 1kVfkV-EP6eYK-kkkVfk             0.000000              0.000000
# JKc8cx-o2eLmv-888D4c             1.000000              0.000000
# iNnngn-A0P52C-ngnnLL             0.000000              0.000000
# kkkVVk-9cCUy3-FFvkFv             0.000000              0.000000
# 4xx88D-w4lMzg-DcY8x8             0.000000              0.000000
# nLngLQ-Wn9DHf-9nnQLn             0.000000              1.000000
# xD8Kx8-r0a1o0-Gxcc8J             1.000000              1.000000
#
#                       キュワワー\nS12a 064/172  ウッウ\nS11 033/100  \
# pick_rate                        0.181818          0.181818
# avg_num_used                     4.000000          1.000000
# pSypy2-7wzfiA-pyXRXM             0.000000          0.000000
# Y48ccY-vlgUnf-KYxxDx             0.000000          1.000000
# dvvwkk-PURvbj-kkFVkv             0.000000          0.000000
# yySSXM-6Ii86T-yyyER3             0.000000          1.000000
# 1kVfkV-EP6eYK-kkkVfk             0.000000          0.000000
# JKc8cx-o2eLmv-888D4c             4.000000          0.000000
# iNnngn-A0P52C-ngnnLL             0.000000          0.000000
# kkkVVk-9cCUy3-FFvkFv             0.000000          0.000000
# 4xx88D-w4lMzg-DcY8x8             0.000000          0.000000
# nLngLQ-Wn9DHf-9nnQLn             4.000000          0.000000
# xD8Kx8-r0a1o0-Gxcc8J             0.000000          0.000000
#
#                       ネオラントV\nS9 104/100  マナフィ\nS12a 029/172  \
# pick_rate                       0.181818            0.181818
# avg_num_used                    1.000000            1.000000
# pSypy2-7wzfiA-pyXRXM            0.000000            0.000000
# Y48ccY-vlgUnf-KYxxDx            1.000000            0.000000
# dvvwkk-PURvbj-kkFVkv            0.000000            0.000000
# yySSXM-6Ii86T-yyyER3            0.000000            1.000000
# 1kVfkV-EP6eYK-kkkVfk            0.000000            0.000000
# JKc8cx-o2eLmv-888D4c            0.000000            0.000000
# iNnngn-A0P52C-ngnnLL            0.000000            0.000000
# kkkVVk-9cCUy3-FFvkFv            0.000000            0.000000
# 4xx88D-w4lMzg-DcY8x8            1.000000            0.000000
# nLngLQ-Wn9DHf-9nnQLn            0.000000            0.000000
# xD8Kx8-r0a1o0-Gxcc8J            0.000000            1.000000
#
#                       コオリッポ\nSI 123/414  ネオラントV\nS9 030/100  \
# pick_rate                      0.181818            0.181818
# avg_num_used                   1.000000            1.000000
# pSypy2-7wzfiA-pyXRXM           0.000000            0.000000
# Y48ccY-vlgUnf-KYxxDx           0.000000            0.000000
# dvvwkk-PURvbj-kkFVkv           0.000000            0.000000
# yySSXM-6Ii86T-yyyER3           1.000000            0.000000
# 1kVfkV-EP6eYK-kkkVfk           0.000000            1.000000
# JKc8cx-o2eLmv-888D4c           0.000000            0.000000
# iNnngn-A0P52C-ngnnLL           0.000000            1.000000
# kkkVVk-9cCUy3-FFvkFv           0.000000            0.000000
# 4xx88D-w4lMzg-DcY8x8           0.000000            0.000000
# nLngLQ-Wn9DHf-9nnQLn           0.000000            0.000000
# xD8Kx8-r0a1o0-Gxcc8J           1.000000            0.000000
#
#                       カイリューV\nS10b 078/071  ネオラントV\nSPZ 001/020  \
# pick_rate                         0.090909             0.090909
# avg_num_used                      1.000000             1.000000
# pSypy2-7wzfiA-pyXRXM              0.000000             0.000000
# Y48ccY-vlgUnf-KYxxDx              0.000000             0.000000
# dvvwkk-PURvbj-kkFVkv              0.000000             0.000000
# yySSXM-6Ii86T-yyyER3              0.000000             0.000000
# 1kVfkV-EP6eYK-kkkVfk              0.000000             0.000000
# JKc8cx-o2eLmv-888D4c              0.000000             0.000000
# iNnngn-A0P52C-ngnnLL              0.000000             0.000000
# kkkVVk-9cCUy3-FFvkFv              0.000000             1.000000
# 4xx88D-w4lMzg-DcY8x8              0.000000             0.000000
# nLngLQ-Wn9DHf-9nnQLn              1.000000             0.000000
# xD8Kx8-r0a1o0-Gxcc8J              0.000000             0.000000
#
#                       ネオラントV\nS9 105/100  ヤレユータン\nS8b 212/184  \
# pick_rate                       0.090909             0.090909
# avg_num_used                    1.000000             1.000000
# pSypy2-7wzfiA-pyXRXM            1.000000             0.000000
# Y48ccY-vlgUnf-KYxxDx            0.000000             0.000000
# dvvwkk-PURvbj-kkFVkv            0.000000             1.000000
# yySSXM-6Ii86T-yyyER3            0.000000             0.000000
# 1kVfkV-EP6eYK-kkkVfk            0.000000             0.000000
# JKc8cx-o2eLmv-888D4c            0.000000             0.000000
# iNnngn-A0P52C-ngnnLL            0.000000             0.000000
# kkkVVk-9cCUy3-FFvkFv            0.000000             0.000000
# 4xx88D-w4lMzg-DcY8x8            0.000000             0.000000
# nLngLQ-Wn9DHf-9nnQLn            0.000000             0.000000
# xD8Kx8-r0a1o0-Gxcc8J            0.000000             0.000000
#
#                       ガラル サンダーV\nSI 217/414  ネオラントV\nS12a 026/172
# pick_rate                          0.090909              0.090909
# avg_num_used                       1.000000              1.000000
# pSypy2-7wzfiA-pyXRXM               1.000000              0.000000
# Y48ccY-vlgUnf-KYxxDx               0.000000              0.000000
# dvvwkk-PURvbj-kkFVkv               0.000000              0.000000
# yySSXM-6Ii86T-yyyER3               0.000000              0.000000
# 1kVfkV-EP6eYK-kkkVfk               0.000000              0.000000
# JKc8cx-o2eLmv-888D4c               0.000000              0.000000
# iNnngn-A0P52C-ngnnLL               0.000000              0.000000
# kkkVVk-9cCUy3-FFvkFv               0.000000              0.000000
# 4xx88D-w4lMzg-DcY8x8               0.000000              0.000000
# nLngLQ-Wn9DHf-9nnQLn               0.000000              1.000000
# xD8Kx8-r0a1o0-Gxcc8J               0.000000              0.000000

# %%
df_list[1]
# Out:
#                                 date prefecture  num_players  rank  バトルVIPパス  \
# pick_rate                        NaN        NaN         <NA>  <NA>       1.0
# avg_num_used                     NaN        NaN         <NA>  <NA>       4.0
# pSypy2-7wzfiA-pyXRXM  2023年01月04日(水)        奈良県           96    10       4.0
# Y48ccY-vlgUnf-KYxxDx  2023年01月02日(月)        東京都           32     3       4.0
# dvvwkk-PURvbj-kkFVkv  2022年12月30日(金)        群馬県           32     2       4.0
# yySSXM-6Ii86T-yyyER3  2022年12月30日(金)        東京都           64     6       4.0
# 1kVfkV-EP6eYK-kkkVfk  2022年12月29日(木)        埼玉県           70    10       4.0
# JKc8cx-o2eLmv-888D4c  2022年12月29日(木)       鹿児島県           48    12       4.0
# iNnngn-A0P52C-ngnnLL  2022年12月28日(水)         京都           32     6       4.0
# kkkVVk-9cCUy3-FFvkFv  2022年12月25日(日)        大阪府           32     3       4.0
# 4xx88D-w4lMzg-DcY8x8  2022年12月23日(金)        大阪府          100     5       4.0
# nLngLQ-Wn9DHf-9nnQLn  2022年12月22日(木)        東京都           70    11       4.0
# xD8Kx8-r0a1o0-Gxcc8J  2022年12月18日(日)        宮崎県           64    10       4.0
#
#                        クイックボール  ヒスイのヘビーボール  回収ネット   あなぬけのヒモ   いれかえカート  \
# pick_rate             1.000000         1.0    1.0  1.000000  1.000000
# avg_num_used          2.727273         1.0    4.0  3.636364  3.181818
# pSypy2-7wzfiA-pyXRXM  2.000000         1.0    4.0  3.000000  4.000000
# Y48ccY-vlgUnf-KYxxDx  3.000000         1.0    4.0  3.000000  3.000000
# dvvwkk-PURvbj-kkFVkv  3.000000         1.0    4.0  3.000000  3.000000
# yySSXM-6Ii86T-yyyER3  2.000000         1.0    4.0  4.000000  2.000000
# 1kVfkV-EP6eYK-kkkVfk  3.000000         1.0    4.0  4.000000  4.000000
# JKc8cx-o2eLmv-888D4c  3.000000         1.0    4.0  4.000000  3.000000
# iNnngn-A0P52C-ngnnLL  2.000000         1.0    4.0  4.000000  3.000000
# kkkVVk-9cCUy3-FFvkFv  3.000000         1.0    4.0  3.000000  3.000000
# 4xx88D-w4lMzg-DcY8x8  3.000000         1.0    4.0  4.000000  3.000000
# nLngLQ-Wn9DHf-9nnQLn  3.000000         1.0    4.0  4.000000  4.000000
# xD8Kx8-r0a1o0-Gxcc8J  3.000000         1.0    4.0  4.000000  3.000000
#
#                       ミラージュゲート  ふつうのつりざお  エネルギーリサイクル     森の封印石  ロストスイーパー  \
# pick_rate                  1.0  1.000000    1.000000  1.000000       1.0
# avg_num_used               4.0  2.181818    1.454545  2.545455       3.0
# pSypy2-7wzfiA-pyXRXM       4.0  3.000000    1.000000  2.000000       3.0
# Y48ccY-vlgUnf-KYxxDx       4.0  3.000000    1.000000  2.000000       3.0
# dvvwkk-PURvbj-kkFVkv       4.0  3.000000    1.000000  2.000000       3.0
# yySSXM-6Ii86T-yyyER3       4.0  2.000000    1.000000  2.000000       3.0
# 1kVfkV-EP6eYK-kkkVfk       4.0  2.000000    2.000000  3.000000       3.0
# JKc8cx-o2eLmv-888D4c       4.0  2.000000    2.000000  3.000000       3.0
# iNnngn-A0P52C-ngnnLL       4.0  1.000000    2.000000  2.000000       3.0
# kkkVVk-9cCUy3-FFvkFv       4.0  2.000000    2.000000  3.000000       3.0
# 4xx88D-w4lMzg-DcY8x8       4.0  2.000000    2.000000  3.000000       3.0
# nLngLQ-Wn9DHf-9nnQLn       4.0  2.000000    1.000000  3.000000       3.0
# xD8Kx8-r0a1o0-Gxcc8J       4.0  2.000000    1.000000  3.000000       3.0
#
#                       トレッキングシューズ      ふうせん      霧の水晶     空の封印石
# pick_rate               0.727273  0.454545  0.272727  0.090909
# avg_num_used            2.125000  1.000000  1.000000  1.000000
# pSypy2-7wzfiA-pyXRXM    0.000000  0.000000  1.000000  0.000000
# Y48ccY-vlgUnf-KYxxDx    0.000000  1.000000  1.000000  0.000000
# dvvwkk-PURvbj-kkFVkv    0.000000  1.000000  1.000000  0.000000
# yySSXM-6Ii86T-yyyER3    2.000000  0.000000  0.000000  1.000000
# 1kVfkV-EP6eYK-kkkVfk    1.000000  0.000000  0.000000  0.000000
# JKc8cx-o2eLmv-888D4c    2.000000  1.000000  0.000000  0.000000
# iNnngn-A0P52C-ngnnLL    3.000000  1.000000  0.000000  0.000000
# kkkVVk-9cCUy3-FFvkFv    2.000000  1.000000  0.000000  0.000000
# 4xx88D-w4lMzg-DcY8x8    2.000000  0.000000  0.000000  0.000000
# nLngLQ-Wn9DHf-9nnQLn    3.000000  0.000000  0.000000  0.000000
# xD8Kx8-r0a1o0-Gxcc8J    2.000000  0.000000  0.000000  0.000000

# %%
df_list[2]
# Out:
#                                 date prefecture  num_players  rank   アクロマの実験
# pick_rate                        NaN        NaN         <NA>  <NA>  1.000000
# avg_num_used                     NaN        NaN         <NA>  <NA>  3.272727
# pSypy2-7wzfiA-pyXRXM  2023年01月04日(水)        奈良県           96    10  4.000000
# Y48ccY-vlgUnf-KYxxDx  2023年01月02日(月)        東京都           32     3  3.000000
# dvvwkk-PURvbj-kkFVkv  2022年12月30日(金)        群馬県           32     2  3.000000
# yySSXM-6Ii86T-yyyER3  2022年12月30日(金)        東京都           64     6  4.000000
# 1kVfkV-EP6eYK-kkkVfk  2022年12月29日(木)        埼玉県           70    10  3.000000
# JKc8cx-o2eLmv-888D4c  2022年12月29日(木)       鹿児島県           48    12  3.000000
# iNnngn-A0P52C-ngnnLL  2022年12月28日(水)         京都           32     6  4.000000
# kkkVVk-9cCUy3-FFvkFv  2022年12月25日(日)        大阪府           32     3  3.000000
# 4xx88D-w4lMzg-DcY8x8  2022年12月23日(金)        大阪府          100     5  3.000000
# nLngLQ-Wn9DHf-9nnQLn  2022年12月22日(木)        東京都           70    11  3.000000
# xD8Kx8-r0a1o0-Gxcc8J  2022年12月18日(日)        宮崎県           64    10  3.000000

# %%
df_list[3]
# Out:
#                                 date prefecture  num_players  rank    ポケストップ
# pick_rate                        NaN        NaN         <NA>  <NA>  1.000000
# avg_num_used                     NaN        NaN         <NA>  <NA>  2.181818
# pSypy2-7wzfiA-pyXRXM  2023年01月04日(水)        奈良県           96    10  2.000000
# Y48ccY-vlgUnf-KYxxDx  2023年01月02日(月)        東京都           32     3  3.000000
# dvvwkk-PURvbj-kkFVkv  2022年12月30日(金)        群馬県           32     2  3.000000
# yySSXM-6Ii86T-yyyER3  2022年12月30日(金)        東京都           64     6  2.000000
# 1kVfkV-EP6eYK-kkkVfk  2022年12月29日(木)        埼玉県           70    10  2.000000
# JKc8cx-o2eLmv-888D4c  2022年12月29日(木)       鹿児島県           48    12  2.000000
# iNnngn-A0P52C-ngnnLL  2022年12月28日(水)         京都           32     6  2.000000
# kkkVVk-9cCUy3-FFvkFv  2022年12月25日(日)        大阪府           32     3  2.000000
# 4xx88D-w4lMzg-DcY8x8  2022年12月23日(金)        大阪府          100     5  2.000000
# nLngLQ-Wn9DHf-9nnQLn  2022年12月22日(木)        東京都           70    11  2.000000
# xD8Kx8-r0a1o0-Gxcc8J  2022年12月18日(日)        宮崎県           64    10  2.000000

# %%
df_list[4]
# Out:
#                                 date prefecture  num_players  rank  基本水エネルギー  \
# pick_rate                        NaN        NaN         <NA>  <NA>  1.000000
# avg_num_used                     NaN        NaN         <NA>  <NA>  4.636364
# pSypy2-7wzfiA-pyXRXM  2023年01月04日(水)        奈良県           96    10  5.000000
# Y48ccY-vlgUnf-KYxxDx  2023年01月02日(月)        東京都           32     3  5.000000
# dvvwkk-PURvbj-kkFVkv  2022年12月30日(金)        群馬県           32     2  5.000000
# yySSXM-6Ii86T-yyyER3  2022年12月30日(金)        東京都           64     6  4.000000
# 1kVfkV-EP6eYK-kkkVfk  2022年12月29日(木)        埼玉県           70    10  5.000000
# JKc8cx-o2eLmv-888D4c  2022年12月29日(木)       鹿児島県           48    12  4.000000
# iNnngn-A0P52C-ngnnLL  2022年12月28日(水)         京都           32     6  5.000000
# kkkVVk-9cCUy3-FFvkFv  2022年12月25日(日)        大阪府           32     3  5.000000
# 4xx88D-w4lMzg-DcY8x8  2022年12月23日(金)        大阪府          100     5  5.000000
# nLngLQ-Wn9DHf-9nnQLn  2022年12月22日(木)        東京都           70    11  4.000000
# xD8Kx8-r0a1o0-Gxcc8J  2022年12月18日(日)        宮崎県           64    10  4.000000
#
#                       基本雷エネルギー  基本超エネルギー  基本闘エネルギー
# pick_rate                  1.0       1.0  0.090909
# avg_num_used               3.0       2.0  1.000000
# pSypy2-7wzfiA-pyXRXM       3.0       2.0  1.000000
# Y48ccY-vlgUnf-KYxxDx       3.0       2.0  0.000000
# dvvwkk-PURvbj-kkFVkv       3.0       2.0  0.000000
# yySSXM-6Ii86T-yyyER3       3.0       2.0  0.000000
# 1kVfkV-EP6eYK-kkkVfk       3.0       2.0  0.000000
# JKc8cx-o2eLmv-888D4c       3.0       2.0  0.000000
# iNnngn-A0P52C-ngnnLL       3.0       2.0  0.000000
# kkkVVk-9cCUy3-FFvkFv       3.0       2.0  0.000000
# 4xx88D-w4lMzg-DcY8x8       3.0       2.0  0.000000
# nLngLQ-Wn9DHf-9nnQLn       3.0       2.0  0.000000
# xD8Kx8-r0a1o0-Gxcc8J       3.0       2.0  0.000000

# %%
decks["others"]
# Out:
# [{'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/kvFf1v-vebuMc-kffFVV',
#   'deck_code': 'kvFf1v-vebuMc-kffFVV',
#   'pokemons': {'アルセウスV\nS-P 267/S-P': 4,
#    'アルセウスVSTAR\nS9 084/100': 3,
#    'ビッパ\nS9 081/100': 2,
#    'ビーダル\nS12a 122/172': 2,
#    'ガラル ファイヤー\nS7D 026/067': 2,
#    'かがやくサーナイト\nS12a 055/172': 1,
#    'ノコッチ\nS12a 118/172': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'しんかのおこう': 1,
#    'あなぬけのヒモ': 1,
#    'ともだちてちょう': 1,
#    'ふつうのつりざお': 1,
#    'こだわりベルト': 1,
#    '大きなおまもり': 2,
#    'ふうせん': 1},
#   'supporters': {'博士の研究': 1,
#    'マリィ': 4,
#    'チェレンの気くばり': 2,
#    'ボスの指令': 1,
#    'セレナ': 1,
#    'ツツジ': 1,
#    'キバナ': 1,
#    'クララ': 1},
#   'stadiums': {'頂への雪道': 2, 'シンオウ神殿': 1},
#   'energies': {'Vガードエネルギー': 1, 'ダブルターボエネルギー': 4, '基本悪エネルギー': 9},
#   'rank': 8,
#   'num_players': 96,
#   'date': '2023年01月04日(水)',
#   'prefecture': '奈良県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/pMypyy-egU9OJ-y3Sppy',
#   'deck_code': 'pMypyy-egU9OJ-y3Sppy',
#   'pokemons': {'ドラパルトVMAX\nS4a 318/190': 3,
#    'ドラパルトV\nS4a 317/190': 3,
#    'アップリュー\nS8b 186/184': 1,
#    'タルップル\nS4a 213/190': 1,
#    'アップリュー\nS7R 050/067': 1,
#    'タルップル\nS7R 051/067': 1,
#    'カジッチュ\nS2 011/096': 3,
#    'ザシアンV\nS8a 018/028': 1,
#    'クロバットV\nS4a 108/190': 2,
#    'マナフィ\nS9 031/100': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'レベルボール': 2,
#    '霧の水晶': 4,
#    'レスキューキャリー': 1,
#    'ポケモンいれかえ': 1,
#    'あなぬけのヒモ': 1,
#    'ともだちてちょう': 1,
#    'やまびこホーン': 1,
#    'ツールスクラッパー': 1,
#    'こだわりベルト': 2,
#    'ふうせん': 1,
#    '森の封印石': 2},
#   'supporters': {'博士の研究': 4, 'マリィ': 1, 'ボスの指令': 1, 'セレナ': 1, 'キバナ': 1},
#   'stadiums': {'シンオウ神殿': 3},
#   'energies': {'基本超エネルギー': 7},
#   'rank': 15,
#   'num_players': 48,
#   'date': '2022年12月29日(木)',
#   'prefecture': '鹿児島県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/8D8a8x-Kgw0Or-8K88xY',
#   'deck_code': '8D8a8x-Kgw0Or-8K88xY',
#   'pokemons': {'カラマネロV\nS2 103/096': 3,
#    'カラマネロVMAX\nS2 071/096': 2,
#    'アルセウスV\nS-P 267/S-P': 4,
#    'アルセウスVSTAR\nS9 084/100': 2,
#    'クロバットV\nSK 008/030': 1,
#    'ネオラントV\nSPD 002/020': 1,
#    'ヨマワル\nS8b 066/184': 2,
#    'ヨノワール\nS8b 198/184': 2,
#    'バケッチャ\nS12a 061/172': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'しんかのおこう': 2,
#    'あなぬけのヒモ': 2,
#    'ふつうのつりざお': 1,
#    'ふしぎなアメ': 3},
#   'supporters': {'マリィ': 3, '博士の研究': 3, 'セレナ': 1, 'キバナ': 2, 'ツツジ': 2},
#   'stadiums': {'頂への雪道': 3},
#   'energies': {'基本悪エネルギー': 7, 'ダブルターボエネルギー': 3, 'キャプチャーエネルギー': 2},
#   'rank': 11,
#   'num_players': 72,
#   'date': '2022年12月29日(木)',
#   'prefecture': '岐阜県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/84DJD8-W7K4UL-x8cxx8',
#   'deck_code': '84DJD8-W7K4UL-x8cxx8',
#   'pokemons': {'クワガノンV\nS2a 025/070': 2,
#    'ライコウV\nSI 137/414': 1,
#    'ガラル ファイヤーV\nS8b 242/184': 2,
#    'ガラル サンダーV\nS8b 237/184': 1,
#    'クロバットV\nS-P 152/S-P': 2,
#    'メタモンV\nS4a 323/190': 1,
#    'かがやくゲッコウガ\nS9a 026/067': 1,
#    'サンダー\nS10b 029/071': 2},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 3,
#    'ヒスイのヘビーボール': 1,
#    'あなぬけのヒモ': 2,
#    'いれかえカート': 2,
#    'ロストスイーパー': 1,
#    'ふうせん': 2,
#    'おはらいグローブ': 1,
#    'こだわりベルト': 1,
#    'タフネスマント': 1,
#    '森の封印石': 1,
#    '空の封印石': 1,
#    'エネルギーつけかえ': 4,
#    'エネルギー転送': 2},
#   'supporters': {'キバナ': 2, 'マリィ': 2, 'ボスの指令': 2, 'アクロマの実験': 3, 'セレナ': 1},
#   'stadiums': {'ロストシティ': 1, 'ガラル鉱山': 1},
#   'energies': {'基本悪エネルギー': 4, 'オーロラエネルギー': 4, '基本闘エネルギー': 1, '基本雷エネルギー': 1},
#   'rank': 7,
#   'num_players': 64,
#   'date': '2022年12月28日(水)',
#   'prefecture': '千葉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/G88x48-6RkPJx-848DJD',
#   'deck_code': 'G88x48-6RkPJx-848DJD',
#   'pokemons': {'アーケオス\nS12 083/098': 3,
#    'クイタラン\nS8 016/100': 2,
#    'オムスターV\nS12 018/098': 2,
#    'アーケン\nS12 082/098': 3,
#    'ライコウV\nS12a 038/172': 1,
#    'エンテイV\nS12a 019/172': 1,
#    'ヤレユータン\nS8b 129/184': 1,
#    'ネオラントV\nS9 105/100': 1,
#    'クロバットV\nSK 008/030': 1,
#    'ルージュラ\nS11a 071/068': 1,
#    'ミルタンク\nS12a 119/172': 1,
#    'マフォクシーV\nS11 101/100': 1,
#    'かがやくリザードン\nS10b 011/071': 1},
#   'tools': {'ヒスイのヘビーボール': 1,
#    'ハイパーボール': 2,
#    'クイックボール': 4,
#    'しんかのおこう': 2,
#    '森の封印石': 2,
#    'こだわりベルト': 1,
#    'タフネスマント': 1,
#    'ポケモンいれかえ': 1,
#    'あなぬけのヒモ': 1},
#   'supporters': {'ハマナのバックアップ': 1,
#    'カイ': 2,
#    'ボスの指令': 2,
#    'マリィ': 2,
#    'ツツジ': 1,
#    '博士の研究': 1,
#    'セレナ': 1},
#   'stadiums': {'頂への雪道': 1, '崩れたスタジアム': 1},
#   'energies': {'ダブルターボエネルギー': 2,
#    'Vガードエネルギー': 1,
#    'ヒート炎エネルギー': 4,
#    'ツインエネルギー': 3,
#    'オーロラエネルギー': 4},
#   'rank': 10,
#   'num_players': 64,
#   'date': '2022年12月28日(水)',
#   'prefecture': '千葉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/kVf1kv-qYy7E4-kk5Fkk',
#   'deck_code': 'kVf1kv-qYy7E4-kk5Fkk',
#   'pokemons': {'アイアント\nS5I 003/070': 3,
#    'チラーミィ\nS9 085/100': 3,
#    'チラチーノ\nS4a 293/190': 3,
#    'ミルタンク\nS9a 058/067': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'イベルタル\nS8a 013/028': 2,
#    'モルペコ\nS4a 062/190': 1,
#    'コオリッポ\nSI 123/414': 2,
#    'カビゴン\nS4 084/100': 1,
#    'メタモン\nS10b 053/071': 1},
#   'tools': {'クイックボール': 4,
#    'レベルボール': 3,
#    '回収ネット': 4,
#    'やまびこホーン': 1,
#    'レスキューキャリー': 3,
#    'ヒスイのヘビーボール': 1,
#    'ふつうのつりざお': 1,
#    'エネくじ': 1},
#   'supporters': {'ボスの指令': 4, 'シバ': 2, 'マリィ': 3, 'セレナ': 2},
#   'stadiums': {'ガラル鉱山': 4},
#   'energies': {'ウォッシュ水エネルギー': 2, 'ツインエネルギー': 3, 'ダブルターボエネルギー': 4},
#   'rank': 4,
#   'num_players': 96,
#   'date': '2022年12月28日(水)',
#   'prefecture': '奈良県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/aKx488-FPzvUJ-cxJ888',
#   'deck_code': 'aKx488-FPzvUJ-cxJ888',
#   'pokemons': {'カビゴン\nS4 084/100': 3,
#    'メタモン\nS10b 053/071': 2,
#    'ミルタンク\nS12a 119/172': 1,
#    'イベルタル\nS8a 013/028': 2,
#    'メグロコ\nS4 070/100': 1,
#    'ヨクバリスV\nS-P 076/S-P': 1,
#    'ピジョットV\nS11 082/100': 1,
#    'ワタシラガV\nS2 010/096': 1,
#    'レジエレキ\nS12a 045/172': 1,
#    'コオリッポ\nSI 123/414': 1,
#    'ナマコブシ\nS8 027/100': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'ルージュラ\nS9a 027/067': 1,
#    'かがやくサーナイト\nS12a 055/172': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 1,
#    'ヒスイのヘビーボール': 1,
#    'トレッキングシューズ': 4,
#    '回収ネット': 2,
#    'タフネスマント': 2,
#    'しあわせタマゴ': 1,
#    '森の封印石': 1,
#    'ロストスイーパー': 1,
#    'レスキューキャリー': 1,
#    'ともだちてちょう': 1},
#   'supporters': {'シマボシ': 1,
#    'シバ': 1,
#    'アスナ': 1,
#    'カゲツ': 1,
#    'シャクヤ': 1,
#    'チェレンの気くばり': 1,
#    'とりつかい': 2,
#    'セレナ': 1,
#    'アクロマの実験': 3,
#    '博士の研究': 1},
#   'stadiums': {'ガラル鉱山': 2},
#   'energies': {'ダブルターボエネルギー': 4, 'ツインエネルギー': 3, 'ウォッシュ水エネルギー': 1},
#   'rank': 5,
#   'num_players': 96,
#   'date': '2022年12月28日(水)',
#   'prefecture': '奈良県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/yUMyMy-hj8u6T-RyMpyS',
#   'deck_code': 'yUMyMy-hj8u6T-RyMpyS',
#   'pokemons': {'アルセウスVSTAR\nS9 084/100': 3,
#    'アルセウスV\nS9 083/100': 4,
#    'カラマネロVMAX\nS2 071/096': 2,
#    'カラマネロV\nS2 070/096': 2,
#    'クロバットV\nSLD 001/020': 1,
#    'かがやくサーナイト\nS12a 055/172': 1},
#   'tools': {'クイックボール': 3,
#    'ハイパーボール': 4,
#    'しんかのおこう': 2,
#    'ポケモンいれかえ': 2,
#    'ビッグパラソル': 2,
#    'クラッシュハンマー': 4},
#   'supporters': {'マリィ': 4, '博士の研究': 2, 'ツツジ': 2, 'ボスの指令': 3, 'セレナ': 1},
#   'stadiums': {'頂への雪道': 3, 'ロストシティ': 2},
#   'energies': {'ダブルターボエネルギー': 4, 'Vガードエネルギー': 2, '基本悪エネルギー': 7},
#   'rank': 14,
#   'num_players': 96,
#   'date': '2022年12月28日(水)',
#   'prefecture': '奈良県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/ypyypy-IyJbRd-MXy2ES',
#   'deck_code': 'ypyypy-IyJbRd-MXy2ES',
#   'pokemons': {'ガラル タチフサグマ\nSI 266/414': 3,
#    'ガラル タチフサグマ\nS1H 035/060': 1,
#    'ガラル マッスグマ\nSI 265/414': 1,
#    'ガラル ジグザグマ\nS1H 033/060': 3,
#    'イベルタル\nS8a 013/028': 1,
#    'インテレオン\nS1W 019/060': 2,
#    'ジメレオン\nS1W 018/060': 3,
#    'メッソン\nS8b 036/184': 4,
#    'マナフィ\nS9 031/100': 1,
#    'かがやくリザードン\nS10b 011/071': 1,
#    'カビゴン\nS8b 126/184': 1},
#   'tools': {'レベルボール': 4,
#    'クイックボール': 3,
#    'ハイパーボール': 2,
#    'ヒスイのヘビーボール': 1,
#    'しんかのおこう': 1,
#    'エネルギー転送': 1,
#    'ふしぎなアメ': 4,
#    '回収ネット': 4,
#    'ダークパッチ': 1,
#    'ふつうのつりざお': 1,
#    'ビッグパラソル': 1},
#   'supporters': {'シロナの覇気': 1,
#    'マリィ': 1,
#    'カイ': 1,
#    'キバナ': 1,
#    'クララ': 1,
#    'ネズ': 1,
#    'ボスの指令': 1},
#   'stadiums': {'シンオウ神殿': 1},
#   'energies': {'基本悪エネルギー': 5, '基本炎エネルギー': 1, 'オーロラエネルギー': 1, 'ツインエネルギー': 1},
#   'rank': 7,
#   'num_players': 64,
#   'date': '2022年12月27日(火)',
#   'prefecture': '千葉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/nPnQQL-3BcVHX-nNnnNL',
#   'deck_code': 'nPnQQL-3BcVHX-nNnnNL',
#   'pokemons': {'ダークライV\nSLD 007/020': 4,
#    'ダークライVSTAR\nSLD 008/020': 3,
#    'ガラル ファイヤーV\nS8b 242/184': 2,
#    'クロバットV\nSLD 001/020': 1,
#    'かがやくゲッコウガ\nS12a 033/172': 1,
#    'ガラル ファイヤー\nS12a 079/172': 1},
#   'tools': {'クイックボール': 3,
#    'ハイパーボール': 4,
#    'ダークパッチ': 4,
#    'ポケモンいれかえ': 2,
#    'ふつうのつりざお': 1,
#    'トレッキングシューズ': 3,
#    'こだわりベルト': 2,
#    'ヒスイのヘビーボール': 1,
#    'バトルVIPパス': 2},
#   'supporters': {'博士の研究': 4, 'キバナ': 1, 'セレナ': 3, 'ツツジ': 1},
#   'stadiums': {'シンオウ神殿': 3},
#   'energies': {'基本悪エネルギー': 14},
#   'rank': 14,
#   'num_players': 48,
#   'date': '2022年12月26日(月)',
#   'prefecture': '大阪府'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/kbV5kk-E2z9SX-vkVvkV',
#   'deck_code': 'kbV5kk-E2z9SX-vkVvkV',
#   'pokemons': {'ウッウ\nS4 027/100': 3,
#    'サシカマス\nS-P 113/S-P': 4,
#    'ミルタンク\nS9a 058/067': 2,
#    'かがやくジラーチ\nS11a 045/068': 1},
#   'tools': {'クイックボール': 4,
#    'バトルVIPパス': 4,
#    'ヒスイのヘビーボール': 2,
#    'レスキューキャリー': 4,
#    'トレッキングシューズ': 4,
#    'ウッウロボ': 3,
#    'あなぬけのヒモ': 2,
#    '回収ネット': 2,
#    'タフネスマント': 2},
#   'supporters': {'博士の研究': 4, 'ルリナ': 3, 'マリィ': 3, 'セレナ': 2},
#   'stadiums': {'頂への雪道': 3},
#   'energies': {'ツインエネルギー': 4, 'ダブルターボエネルギー': 4},
#   'rank': 11,
#   'num_players': 100,
#   'date': '2022年12月26日(月)',
#   'prefecture': '大阪府'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/kkvVVw-dqAMRE-kk5kV5',
#   'deck_code': 'kkvVVw-dqAMRE-kk5kV5',
#   'pokemons': {'ヒスイ ドレディアVSTAR\nS10D 008/067': 2,
#    'ヒスイ ドレディアV\nS10D 007/067': 2,
#    'ドダイトス\nS9 008/100': 3,
#    'ハヤシガメ\nS9 007/100': 4,
#    'ナエトル\nS9 006/100': 4,
#    'ゴリランダー\nS4a 008/190': 2,
#    'バチンキー\nS4a 007/190': 1,
#    'サルノリ\nSA 006/023': 2,
#    'アゲハント\nS10a 006/071': 1,
#    'カラサリス\nS10a 005/071': 1,
#    'ケムッソ\nS10a 004/071': 1,
#    'スピアー\nS3a 003/076': 1,
#    'ゲンガー\nS10a 023/071': 1},
#   'tools': {'バトルVIPパス': 4,
#    'ふしぎなアメ': 3,
#    'ふつうのつりざお': 3,
#    'あなぬけのヒモ': 2,
#    'こだわりベルト': 2,
#    'ハイパーボール': 1},
#   'supporters': {'ピオニー': 4, 'オニオン': 2, 'とりつかい': 1, 'マリィ': 1, 'キバナ': 1},
#   'stadiums': {'ターフスタジアム': 3},
#   'energies': {'キャプチャーエネルギー': 2, '基本草エネルギー': 6},
#   'rank': 16,
#   'num_players': 64,
#   'date': '2022年12月25日(日)',
#   'prefecture': '長崎県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/nn6LNn-zvc7Sh-NngnPg',
#   'deck_code': 'nn6LNn-zvc7Sh-NngnPg',
#   'pokemons': {'オムスターV\nS12 018/098': 3,
#    'かがやくジラーチ\nS11a 045/068': 1,
#    'エイパム\nS10b 057/071': 3,
#    'エテボース\nS10b 058/071': 3,
#    'ミルタンク\nS12a 119/172': 1,
#    'マフォクシーV\nS11 017/100': 1,
#    'ネオラントV\nS9 030/100': 1,
#    'アーケン\nS12 082/098': 3,
#    'アーケオス\nS-P 327/S-P': 1,
#    'アーケオス\nS12 083/098': 2,
#    'マナフィ\nS12a 029/172': 1},
#   'tools': {'森の封印石': 1,
#    '大地の封印石': 1,
#    'しんかのおこう': 1,
#    'ヒスイのヘビーボール': 1,
#    'ハイパーボール': 2,
#    'ポケモンいれかえ': 1,
#    'クイックボール': 1,
#    'こだわりベルト': 1,
#    'ロストスイーパー': 1,
#    'あなぬけのヒモ': 1,
#    'レベルボール': 1},
#   'supporters': {'セレナ': 2, 'カイ': 2, 'ボスの指令': 1, 'ヒナツ': 1, 'マリィ': 1},
#   'stadiums': {'頂への雪道': 2, 'ルミナスメイズの森': 1},
#   'energies': {'ヒート炎エネルギー': 1,
#    'オーロラエネルギー': 2,
#    'ツインエネルギー': 4,
#    'ダブルターボエネルギー': 4,
#    'パワフル無色エネルギー': 2,
#    'ウォッシュ水エネルギー': 2,
#    'キャプチャーエネルギー': 1,
#    'ギフトエネルギー': 1},
#   'rank': 10,
#   'num_players': 64,
#   'date': '2022年12月25日(日)',
#   'prefecture': '東京都'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/iLLNiL-aoE7mb-nNinnn',
#   'deck_code': 'iLLNiL-aoE7mb-nNinnn',
#   'pokemons': {'アルセウスVSTAR\nS12a 127/172': 3,
#    'アルセウスV\nS-P 267/S-P': 3,
#    'イベルタル\nS8a 013/028': 4,
#    'カビゴン\nS8b 126/184': 4,
#    'ヤレユータン\nS8b 212/184': 1,
#    'ノコッチ\nS12a 118/172': 1,
#    'かがやくサーナイト\nS12a 055/172': 1,
#    'ドラピオンV\nS12a 085/172': 2},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'ポケモンいれかえ': 1,
#    'あなぬけのヒモ': 1,
#    '回収ネット': 2,
#    '大きなおまもり': 2,
#    'ロストスイーパー': 1},
#   'supporters': {'博士の研究': 3,
#    'マリィ': 2,
#    'ボスの指令': 3,
#    'キバナ': 1,
#    'チェレンの気くばり': 2,
#    'カゲツ': 1,
#    'クララ': 1},
#   'stadiums': {'崩れたスタジアム': 1},
#   'energies': {'ダブルターボエネルギー': 4, 'ツインエネルギー': 2, '基本悪エネルギー': 6},
#   'rank': 2,
#   'num_players': 32,
#   'date': '2022年12月25日(日)',
#   'prefecture': '千葉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/488x88-GAY35X-8D8c48',
#   'deck_code': '488x88-GAY35X-8D8c48',
#   'pokemons': {'ゼラオラV\nS12a 040/172': 3,
#    'ゼラオラVMAX\nS12a 041/172': 3,
#    'アルセウスV\nS12a 126/172': 4,
#    'アルセウスVSTAR\nS12a 127/172': 3},
#   'tools': {'ハイパーボール': 4,
#    'ポケギア3.0': 3,
#    'キャンセルコロン': 1,
#    'すごいきずぐすり': 2,
#    'ポケモンいれかえ': 2,
#    'クイックボール': 3},
#   'supporters': {'チェレンの気くばり': 2,
#    'ボスの指令': 2,
#    'セレナ': 2,
#    'ジャッジマン': 2,
#    'マリィ': 3,
#    '博士の研究': 4},
#   'stadiums': {'シンオウ神殿': 2, '頂への雪道': 3, 'ロストシティ': 1},
#   'energies': {'基本雷エネルギー': 7, 'ダブルターボエネルギー': 4},
#   'rank': 7,
#   'num_players': 32,
#   'date': '2022年12月25日(日)',
#   'prefecture': '兵庫県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/8x8x88-g7uvqt-884cDx',
#   'deck_code': '8x8x88-g7uvqt-884cDx',
#   'pokemons': {'ヒスイ ウインディV\nS12 046/098': 4,
#    'クロバットV\nSK 008/030': 1,
#    'ガラル サンダー\nS12a 073/172': 3,
#    'ヤレユータン\nS8b 212/184': 1,
#    'かがやくゲッコウガ\nS12a 033/172': 1},
#   'tools': {'クイックボール': 4,
#    'フェザーボール': 2,
#    '回収ネット': 4,
#    'トレッキングシューズ': 4,
#    'ガッツのつるはし': 4,
#    'エネルギー回収': 3,
#    'あなぬけのヒモ': 2,
#    '学習装置': 3,
#    '空の封印石': 1},
#   'supporters': {'博士の研究': 4, 'セレナ': 2, 'ボスの指令': 1},
#   'stadiums': {'シンオウ神殿': 2},
#   'energies': {'基本闘エネルギー': 14},
#   'rank': 14,
#   'num_players': 80,
#   'date': '2022年12月25日(日)',
#   'prefecture': '東京都'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/FFFFkk-ArCoxh-Vkbfkk',
#   'deck_code': 'FFFFkk-ArCoxh-Vkbfkk',
#   'pokemons': {'フリーザー\nS11a 024/068': 3,
#    'メッソン\nS5a 016/070': 4,
#    'ジメレオン\nS4a 225/190': 4,
#    'インテレオン\nS4a 226/190': 2,
#    'インテレオン\nS5a 018/070': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'コオリッポ\nS7D 009/067': 1,
#    'かがやくフーディン\nS11a 031/068': 1,
#    'ドラピオンV\nS12a 085/172': 1},
#   'tools': {'ヒスイのヘビーボール': 1,
#    'クイックボール': 3,
#    '回収ネット': 4,
#    'しんかのおこう': 3,
#    'たっぷりバケツ': 2,
#    'レベルボール': 4,
#    'ふつうのつりざお': 1,
#    'レスキューキャリー': 1,
#    'ともだちてちょう': 1,
#    'ロストスイーパー': 1,
#    'ふしぎなアメ': 1,
#    'きんきゅうゼリー': 3,
#    'ふうせん': 1},
#   'supporters': {'カイ': 4, 'ボスの指令': 1, 'ハマナのバックアップ': 1, 'キバナ': 2, 'クララ': 1},
#   'stadiums': {'トレーニングコート': 1},
#   'energies': {'ウォッシュ水エネルギー': 2, '基本水エネルギー': 4},
#   'rank': 12,
#   'num_players': 76,
#   'date': '2022年12月25日(日)',
#   'prefecture': '福岡県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/8Yx88D-r1R3ag-48aYc8',
#   'deck_code': '8Yx88D-r1R3ag-48aYc8',
#   'pokemons': {'クワガノンV\nS2a 073/070': 2,
#    'ライコウV\nS12a 038/172': 1,
#    'サンダー\nS10b 029/071': 2,
#    'ガラル サンダーV\nS5a 075/070': 1,
#    'ガラル ファイヤーV\nS5a 077/070': 2,
#    'ミュウ\nS12a 052/172': 3,
#    'かがやくゲッコウガ\nS9a 026/067': 1,
#    'ネオラントV\nS9 104/100': 1,
#    'クロバットV\nS-P 152/S-P': 1},
#   'tools': {'クイックボール': 4,
#    'バトルVIPパス': 3,
#    '回収ネット': 3,
#    'エネルギーつけかえ': 3,
#    'エネルギー転送': 2,
#    '森の封印石': 2,
#    'あなぬけのヒモ': 1,
#    'いれかえカート': 1,
#    'ふうせん': 1,
#    'ヒスイのヘビーボール': 1,
#    'タフネスマント': 1,
#    'こだわりベルト': 1,
#    'ロストスイーパー': 1},
#   'supporters': {'ボスの指令': 3, 'マリィ': 3, 'セイボリー': 1, 'とりつかい': 1, 'キバナ': 1},
#   'stadiums': {'ポケストップ': 1, '頂への雪道': 1},
#   'energies': {'スピード雷エネルギー': 4, '基本雷エネルギー': 2, '基本悪エネルギー': 4, '基本闘エネルギー': 1},
#   'rank': 8,
#   'num_players': 60,
#   'date': '2022年12月24日(土)',
#   'prefecture': '埼玉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/yRMy2p-6woGMR-UyySMS',
#   'deck_code': 'yRMy2p-6woGMR-UyySMS',
#   'pokemons': {'インテレオン\nS4a 041/190': 2,
#    'インテレオン\nSI 118/414': 1,
#    'ジメレオン\nS4a 040/190': 3,
#    'メッソン\nSI 116/414': 4,
#    'モスノウ\nS8b 040/184': 2,
#    'ユキハミ\nS4a 047/190': 2,
#    'フリーザー\nS11a 024/068': 2,
#    'かがやくゲッコウガ\nS12a 033/172': 1,
#    'コオリッポ\nSI 123/414': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'ドラピオンV\nS12a 085/172': 1,
#    'カイオーガ\nS11a 030/068': 1},
#   'tools': {'レベルボール': 4,
#    'クイックボール': 2,
#    'しんかのおこう': 2,
#    '回収ネット': 3,
#    'たっぷりバケツ': 2,
#    'バトルVIPパス': 1,
#    'ヒスイのヘビーボール': 1,
#    'ふうせん': 1,
#    'ふしぎなアメ': 1,
#    'きんきゅうゼリー': 2,
#    'あなぬけのヒモ': 1,
#    'キャンセルコロン': 1},
#   'supporters': {'カイ': 4, 'ボスの指令': 2, 'ルリナ': 2, 'マリィ': 2},
#   'stadiums': {'トレーニングコート': 1},
#   'energies': {'基本水エネルギー': 6, 'ウォッシュ水エネルギー': 1},
#   'rank': 15,
#   'num_players': 60,
#   'date': '2022年12月24日(土)',
#   'prefecture': '埼玉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/Vkkfkk-Qtucm8-Vk5fkk',
#   'deck_code': 'Vkkfkk-Qtucm8-Vk5fkk',
#   'pokemons': {'ゲノセクトV\nS8 109/100': 1,
#    'ゲノセクトV\nS8 108/100': 1,
#    'ゲノセクトV\nS8 069/100': 2,
#    'オドリドリ\nS8 017/100': 1,
#    'メロエッタ\nS8 048/100': 1,
#    'ガラル ニャース\nSP1 001/007': 2,
#    'ガラル ニャイキング\nS1W 041/060': 2},
#   'tools': {'パワータブレット': 4,
#    'ターボパッチ': 2,
#    'メタルソーサー': 4,
#    'ハイパーボール': 1,
#    'クイックボール': 4,
#    'ともだちてちょう': 1,
#    'ふうせん': 1,
#    'こだわりベルト': 2,
#    'ポケモンいれかえ': 2,
#    'あなぬけのヒモ': 2,
#    'バトルVIPパス': 3,
#    'ヒスイのヘビーボール': 1,
#    '学習装置': 1,
#    '森の封印石': 1,
#    '空の封印石': 1},
#   'supporters': {'カミツレのきらめき': 1,
#    'キバナ': 1,
#    'シマボシ': 1,
#    'セレナ': 1,
#    'ピオニー': 1,
#    'マリィ': 1,
#    'ボスの指令': 1,
#    'ツツジ': 1},
#   'stadiums': {'ローズタワー': 1, 'ポケストップ': 1},
#   'energies': {'フュージョンエネルギー': 4, '基本鋼エネルギー': 5},
#   'rank': 8,
#   'num_players': 32,
#   'date': '2022年12月24日(土)',
#   'prefecture': '東京都'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/VkfFkk-koYaSq-bkkfdk',
#   'deck_code': 'VkfFkk-koYaSq-bkkfdk',
#   'pokemons': {'れんげきウーラオスVMAX\nS8b 241/184': 2,
#    'スピアー\nS8b 003/184': 3,
#    'ヤレユータンV\nS10P 076/067': 4,
#    'ネオラントV\nS12a 026/172': 2,
#    'ガラル ニャース\nS4a 285/190': 1,
#    'レントラー\nS12 028/098': 3,
#    'ヤレユータン\nS8b 212/184': 1},
#   'tools': {'ハイパーボール': 4,
#    'クイックボール': 4,
#    'こだわりベルト': 2,
#    '森の封印石': 2,
#    'ポケモンいれかえ': 3,
#    'ふうせん': 2,
#    'ふつうのつりざお': 1,
#    'エネルギー転送': 4,
#    'あなぬけのヒモ': 2,
#    'スマホロトム': 2,
#    'ロストスイーパー': 1},
#   'supporters': {'マスタード': 3, 'ボスの指令': 1},
#   'stadiums': {'ポケストップ': 1, 'トレーニングコート': 2},
#   'energies': {'れんげきエネルギー': 3, '基本闘エネルギー': 2, '基本草エネルギー': 3},
#   'rank': 13,
#   'num_players': 48,
#   'date': '2022年12月24日(土)',
#   'prefecture': '京都'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/5fkfvk-WpTKh5-kfVVkk',
#   'deck_code': '5fkfvk-WpTKh5-kfVVkk',
#   'pokemons': {'ビクティニVMAX\nS5R 013/070': 2,
#    'ビクティニV\nS5R 072/070': 2,
#    'ビクティニV\nSA 003/023': 2,
#    'エンテイV\nSI 056/414': 1,
#    'かがやくリザードン\nS10b 011/071': 1,
#    'ファイヤー\nS9 018/100': 1,
#    'ギャロップ\nS12 011/098': 2,
#    'ポニータ\nS-P 310/S-P': 2,
#    'クロバットV\nS-P 152/S-P': 2,
#    'ネオラントV\nS9 104/100': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'トレッキングシューズ': 4,
#    'ポケモンいれかえ': 2,
#    'やまびこホーン': 1,
#    'ふうせん': 1,
#    'こだわりベルト': 2,
#    '森の封印石': 2},
#   'supporters': {'博士の研究': 3,
#    'マリィ': 2,
#    'ボスの指令': 2,
#    'セレナ': 2,
#    'ツツジ': 1,
#    'クララ': 1},
#   'stadiums': {'マグマの滝壺': 3},
#   'energies': {'基本炎エネルギー': 10},
#   'rank': 8,
#   'num_players': 64,
#   'date': '2022年12月24日(土)',
#   'prefecture': '千葉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/nPQnnL-Ym8Jxf-NnNiLn',
#   'deck_code': 'nPQnnL-Ym8Jxf-NnNiLn',
#   'pokemons': {'メッソン\nS8b 036/184': 4,
#    'ジメレオン\nS4a 040/190': 3,
#    'インテレオン\nS4a 041/190': 2,
#    'インテレオン\nSI 118/414': 1,
#    'アローラロコンV\nS11a 022/068': 1,
#    'アローラロコンVSTAR\nS11a 023/068': 1,
#    'ユキハミ\nS4a 047/190': 2,
#    'モスノウ\nS8b 040/184': 2,
#    'かがやくゲッコウガ\nS9a 026/067': 1,
#    'フリーザー\nS11a 024/068': 1,
#    'コオリッポ\nSI 123/414': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'ドラピオンV\nS11 066/100': 1},
#   'tools': {'クイックボール': 2,
#    'レベルボール': 4,
#    'しんかのおこう': 2,
#    'ヒスイのヘビーボール': 1,
#    'バトルVIPパス': 1,
#    '回収ネット': 4,
#    'たっぷりバケツ': 3,
#    'エネルギー回収': 1,
#    'ふしぎなアメ': 1,
#    'ビッグパラソル': 1,
#    'ふうせん': 1},
#   'supporters': {'カイ': 4, 'ルリナ': 2, 'マリィ': 1, 'キバナ': 1, 'ボスの指令': 2},
#   'stadiums': {'トレーニングコート': 1},
#   'energies': {'基本水エネルギー': 6, 'ウォッシュ水エネルギー': 1},
#   'rank': 1,
#   'num_players': 32,
#   'date': '2022年12月24日(土)',
#   'prefecture': '和歌山県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/ninnnN-DWGqxA-LNngnn',
#   'deck_code': 'ninnnN-DWGqxA-LNngnn',
#   'pokemons': {'オムスターV\nS12 018/098': 4,
#    'ネオラントV\nSPD 002/020': 2,
#    'アーケン\nS12 082/098': 3,
#    'アーケオス\nS12 083/098': 3,
#    'アローラロコンV\nS11a 022/068': 2,
#    'アローラロコンVSTAR\nS11a 023/068': 2,
#    'エンペルトV\nSI 100/414': 2,
#    'マナフィ\nS12a 029/172': 1,
#    'かがやくリザードン\nS10b 011/071': 1,
#    'イベルタル\nS4a 117/190': 1},
#   'tools': {'クイックボール': 4,
#    'しんかのおこう': 3,
#    'ロストスイーパー': 2,
#    'あなぬけのヒモ': 2,
#    '森の封印石': 2,
#    'げんきのハチマキ': 1},
#   'supporters': {'カイ': 4, 'マリィ': 4, 'ボスの指令': 2},
#   'stadiums': {'崩れたスタジアム': 1, 'エイチ湖': 1},
#   'energies': {'キャプチャーエネルギー': 2,
#    'Vガードエネルギー': 2,
#    'ツインエネルギー': 1,
#    'ダブルターボエネルギー': 1,
#    'オーロラエネルギー': 4,
#    'ウォッシュ水エネルギー': 2,
#    'ハイド悪エネルギー': 1},
#   'rank': 9,
#   'num_players': 64,
#   'date': '2022年12月23日(金)',
#   'prefecture': '東京都'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/nnPNnL-BiPMjY-ggnLLL',
#   'deck_code': 'nnPNnL-BiPMjY-ggnLLL',
#   'pokemons': {'ミルタンク\nS9a 058/067': 1,
#    'メタモン\nS12a 117/172': 4,
#    'ヤレユータン\nS1H 049/060': 1,
#    'イベルタル\nS8a 013/028': 2,
#    'コオリッポ\nS7D 009/067': 2,
#    'ルージュラ\nS9a 027/067': 2,
#    'レジエレキ\nS12a 045/172': 1,
#    'メグロコ\nS4 070/100': 1,
#    'マナフィ\nS12a 029/172': 1},
#   'tools': {'ビッグパラソル': 2,
#    'レベルボール': 2,
#    'クイックボール': 4,
#    'ハイパーボール': 2,
#    'ともだちてちょう': 2,
#    'レスキューキャリー': 1,
#    '回収ネット': 3,
#    'トレッキングシューズ': 3},
#   'supporters': {'シマボシ': 2,
#    'カゲツ': 1,
#    'ネズ': 1,
#    'シャクヤ': 1,
#    '野盗三姉妹': 1,
#    'セレナ': 2,
#    '博士の研究': 4},
#   'stadiums': {'ガラル鉱山': 2, '頂への雪道': 2},
#   'energies': {'ウォッシュ水エネルギー': 3, 'ツインエネルギー': 4, 'ダブルターボエネルギー': 3},
#   'rank': 11,
#   'num_players': 126,
#   'date': '2022年12月22日(木)',
#   'prefecture': '神奈川県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/yySyM2-BCD69x-XpXM3p',
#   'deck_code': 'yySyM2-BCD69x-XpXM3p',
#   'pokemons': {'アルセウスV\nS9 083/100': 4,
#    'アルセウスVSTAR\nS9 084/100': 2,
#    'ヒスイ ヌメルゴンV\nS10a 056/071': 2,
#    'ヒスイ ヌメルゴンVSTAR\nS10a 057/071': 2,
#    'アローラロコンV\nS11a 022/068': 1,
#    'アローラロコンVSTAR\nS11a 023/068': 1,
#    'かがやくサーナイト\nS10a 027/071': 1,
#    'ドラピオンV\nS12a 085/172': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 3,
#    'しんかのおこう': 2,
#    'ポケモンいれかえ': 2,
#    'ビッグパラソル': 2,
#    'すごいきずぐすり': 3},
#   'supporters': {'アクロマの実験': 4,
#    'メロン': 3,
#    'マリィ': 1,
#    'ボスの指令': 2,
#    '博士の研究': 1,
#    'セイボリー': 1,
#    'ツツジ': 1},
#   'stadiums': {'結晶の洞窟': 2, '頂への雪道': 2},
#   'energies': {'ダブルターボエネルギー': 4, '基本水エネルギー': 5, '基本鋼エネルギー': 4},
#   'rank': 15,
#   'num_players': 100,
#   'date': '2022年12月19日(月)',
#   'prefecture': '埼玉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/MypyMy-V9JAzd-pyMypy',
#   'deck_code': 'MypyMy-V9JAzd-pyMypy',
#   'pokemons': {'アルセウスV\nS9 112/100': 4,
#    'アルセウスVSTAR\nS9 084/100': 4,
#    'スターミーV\nS9a 075/067': 1,
#    'ドラピオンV\nS11 107/100': 1,
#    'クロバットV\nS3 105/100': 1,
#    'ネオラントV\nS9 104/100': 1,
#    'かがやくサーナイト\nS12a 055/172': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'しんかのおこう': 1,
#    '大きなおまもり': 3,
#    'あなぬけのヒモ': 1,
#    'ポケモンいれかえ': 1,
#    'ふつうのつりざお': 1,
#    'すごいきずぐすり': 2},
#   'supporters': {'メロン': 2,
#    'セレナ': 2,
#    'マリィ': 3,
#    'チェレンの気くばり': 2,
#    '博士の研究': 2,
#    'ボスの指令': 2},
#   'stadiums': {'エイチ湖': 2, '頂への雪道': 1, 'シンオウ神殿': 1, 'ポケストップ': 1},
#   'energies': {'基本水エネルギー': 8, 'ダブルターボエネルギー': 4},
#   'rank': 16,
#   'num_players': 64,
#   'date': '2022年12月18日(日)',
#   'prefecture': '東京都'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/LiL6Hn-gEY8pe-nNgnLL',
#   'deck_code': 'LiL6Hn-gEY8pe-nNgnLL',
#   'pokemons': {'メッソン\nS5a 016/070': 4,
#    'ジメレオン\nS1W 018/060': 4,
#    'インテレオン\nS1W 019/060': 2,
#    'インテレオン\nS5a 018/070': 1,
#    'そらをとぶピカチュウV\nS8a 023/028': 1,
#    'そらをとぶピカチュウVMAX\nS8a 024/028': 1,
#    'ライコウV\nSI 137/414': 1,
#    'ゼラオラ\nS3a 021/076': 1,
#    'かがやくリザードン\nS10b 011/071': 1,
#    'カビゴン\nS8b 126/184': 1,
#    'マナフィ\nS9 031/100': 1},
#   'tools': {'クイックボール': 4,
#    'レベルボール': 2,
#    'しんかのおこう': 2,
#    'ヒスイのヘビーボール': 1,
#    '回収ネット': 2,
#    'こだわりベルト': 2,
#    'ふつうのつりざお': 2,
#    'エネルギー転送': 1,
#    'あなぬけのヒモ': 1,
#    '空の封印石': 1,
#    '森の封印石': 1,
#    'ふしぎなアメ': 1},
#   'supporters': {'マリィ': 2,
#    '博士の研究': 1,
#    'ツツジ': 1,
#    'キバナ': 3,
#    'クララ': 1,
#    'セレナ': 1,
#    'ボスの指令': 1},
#   'stadiums': {'シンオウ神殿': 2, 'マグマの滝壺': 1},
#   'energies': {'基本雷エネルギー': 3, '基本炎エネルギー': 3, '基本水エネルギー': 2, 'キャプチャーエネルギー': 1},
#   'rank': 3,
#   'num_players': 100,
#   'date': '2022年12月18日(日)',
#   'prefecture': '埼玉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/cD8xac-6yKqQD-88xJ8x',
#   'deck_code': 'cD8xac-6yKqQD-88xJ8x',
#   'pokemons': {'ライチュウV\nS9 106/100': 1,
#    'メリープ\nS6K 018/070': 3,
#    'モココ\nS12a 037/172': 3,
#    'ゼクロム\nS8b 053/184': 2,
#    'かがやくゲッコウガ\nS9a 026/067': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'ドラピオンV\nS11 066/100': 1,
#    'サンダー\nS10b 029/071': 1,
#    'ヒスイ バスラオ\nS12a 030/172': 1,
#    'カビゴン\nS10a 077/071': 1},
#   'tools': {'レベルボール': 3,
#    'こだわりベルト': 1,
#    '空の封印石': 1,
#    'ヒスイのヘビーボール': 1,
#    'ふうせん': 2,
#    'ハイパーボール': 2,
#    '回収ネット': 2,
#    'ふつうのつりざお': 1,
#    'ポケモンいれかえ': 1,
#    'トレッキングシューズ': 4,
#    'ともだちてちょう': 1,
#    'やまびこホーン': 1,
#    'クイックボール': 4},
#   'supporters': {'マリィ': 3, 'ボスの指令': 2, 'セイボリー': 1, '博士の研究': 3, 'ツツジ': 1},
#   'stadiums': {'頂への雪道': 1, 'シンオウ神殿': 1},
#   'energies': {'スピード雷エネルギー': 2, '基本雷エネルギー': 7},
#   'rank': 12,
#   'num_players': 100,
#   'date': '2022年12月18日(日)',
#   'prefecture': '埼玉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/dvkVVk-05u4yv-1kFdV5',
#   'deck_code': 'dvkVVk-05u4yv-1kFdV5',
#   'pokemons': {'メッソン\nSI 116/414': 4,
#    'ジメレオン\nS4a 040/190': 3,
#    'インテレオン\nS4a 041/190': 2,
#    'インテレオン\nS5a 018/070': 1,
#    'かがやくゲッコウガ\nS12a 033/172': 1,
#    'ユキハミ\nS4a 047/190': 2,
#    'モスノウ\nS8b 040/184': 2,
#    'コオリッポ\nSI 123/414': 1,
#    'フリーザー\nS11a 024/068': 2,
#    'マナフィ\nS12a 029/172': 1,
#    'アローラロコンV\nS11a 022/068': 1,
#    'アローラロコンVSTAR\nS11a 023/068': 1,
#    'ドラピオンV\nS12a 085/172': 1},
#   'tools': {'クイックボール': 2,
#    'レベルボール': 4,
#    'しんかのおこう': 2,
#    'ヒスイのヘビーボール': 1,
#    '回収ネット': 3,
#    'きんきゅうゼリー': 2,
#    'たっぷりバケツ': 2,
#    'ふうせん': 1,
#    'バトルVIPパス': 1,
#    'ふしぎなアメ': 1},
#   'supporters': {'カイ': 4, 'ルリナ': 2, 'ボスの指令': 3, 'マリィ': 1, 'キバナ': 1},
#   'stadiums': {'トレーニングコート': 1},
#   'energies': {'基本水エネルギー': 6, 'ウォッシュ水エネルギー': 1},
#   'rank': 3,
#   'num_players': 64,
#   'date': '2022年12月18日(日)',
#   'prefecture': '千葉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/gnngLn-6H6HhO-inQNPL',
#   'deck_code': 'gnngLn-6H6HhO-inQNPL',
#   'pokemons': {'ヒスイ ウインディV\nS12 046/098': 4,
#    'ガラル サンダー\nS12a 073/172': 4,
#    'ヤレユータン\nS8b 212/184': 1,
#    'ネオラントV\nSPD 002/020': 1,
#    'ドラピオンV\nS12a 085/172': 1,
#    'クロバットV\nS8b 243/184': 1,
#    'かがやくゲッコウガ\nS12a 033/172': 1},
#   'tools': {'タフネスマント': 2,
#    'クイックボール': 4,
#    'ガッツのつるはし': 4,
#    '回収ネット': 4,
#    'いれかえカート': 1,
#    '空の封印石': 1,
#    'あなぬけのヒモ': 1},
#   'supporters': {'ボスの指令': 1, '博士の研究': 4, 'マリィ': 1, 'ソニア': 1},
#   'stadiums': {'トレーニングコート': 1, 'シンオウ神殿': 3},
#   'energies': {'基本闘エネルギー': 18},
#   'rank': 6,
#   'num_players': 32,
#   'date': '2022年12月18日(日)',
#   'prefecture': '兵庫県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/PPLnLL-Xrmd3U-nHingn',
#   'deck_code': 'PPLnLL-Xrmd3U-nHingn',
#   'pokemons': {'アルセウスVSTAR\nS9 084/100': 2,
#    'アルセウスV\nS9 083/100': 2,
#    'はくばバドレックスVMAX\nS6H 028/070': 2,
#    'はくばバドレックスV\nS6H 027/070': 2,
#    'ネオラントV\nS9 030/100': 1,
#    'かがやくゲッコウガ\nS9a 026/067': 1,
#    'ミルタンク\nS9a 058/067': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'イベルタル\nS8a 013/028': 1},
#   'tools': {'クイックボール': 3,
#    'しんかのおこう': 2,
#    'ハイパーボール': 3,
#    'こだわりベルト': 2,
#    'たっぷりバケツ': 1,
#    'ふうせん': 1,
#    'ポケモンいれかえ': 1,
#    'ポケモンキャッチャー': 4,
#    'バトルVIPパス': 1,
#    'ヒスイのヘビーボール': 1,
#    'ふつうのつりざお': 1,
#    'やまびこホーン': 1,
#    'ロストスイーパー': 1},
#   'supporters': {'メロン': 4, 'ボスの指令': 2, 'マリィ': 1, 'ツツジ': 1, 'カイ': 1, 'キバナ': 1},
#   'stadiums': {'頂への雪道': 1, 'シンオウ神殿': 1},
#   'energies': {'基本水エネルギー': 9, 'ダブルターボエネルギー': 3, 'ウォッシュ水エネルギー': 1},
#   'rank': 5,
#   'num_players': 64,
#   'date': '2022年12月18日(日)',
#   'prefecture': '神奈川県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/fVVV5V-gH7CGJ-1FkkkV',
#   'deck_code': 'fVVV5V-gH7CGJ-1FkkkV',
#   'pokemons': {'メタモン\nS12a 117/172': 4,
#    'コオリッポ\nS7D 009/067': 1,
#    'イベルタル\nS8a 013/028': 2,
#    'ルージュラ\nS9a 027/067': 2,
#    'ナマコブシ\nS8 027/100': 1,
#    'メグロコ\nS4 070/100': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'ワタシラガV\nS2 097/096': 1,
#    'かがやくジラーチ\nS11a 045/068': 1,
#    'ミルタンク\nS12a 119/172': 1},
#   'tools': {'トレッキングシューズ': 3,
#    'ポケギア3.0': 2,
#    'ロストスイーパー': 1,
#    'エネくじ': 2,
#    '回収ネット': 3,
#    'クイックボール': 4,
#    'ヒスイのヘビーボール': 1,
#    'ビッグパラソル': 1,
#    'しあわせタマゴ': 1,
#    'レスキューキャリー': 1,
#    'クラッシュハンマー': 2,
#    'ハイパーボール': 2},
#   'supporters': {'カイ': 2, '博士の研究': 4, 'とりつかい': 2, 'シャクヤ': 1},
#   'stadiums': {'ガラル鉱山': 3, '頂への雪道': 1},
#   'energies': {'ウォッシュ水エネルギー': 2, 'ダブルターボエネルギー': 4, 'ツインエネルギー': 3},
#   'rank': 9,
#   'num_players': 64,
#   'date': '2022年12月18日(日)',
#   'prefecture': '神奈川県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/VVVFkd-27IGM7-vkk1Vd',
#   'deck_code': 'VVVFkd-27IGM7-vkk1Vd',
#   'pokemons': {'アルセウスV\nS9 083/100': 4,
#    'アルセウスVSTAR\nS9 084/100': 3,
#    'メルメタルV\nS10b 047/071': 3,
#    'メルメタルVMAX\nS10b 048/071': 3},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'ポケモンいれかえ': 3,
#    'こだわりベルト': 1,
#    'ツールスクラッパー': 1,
#    'しんかのおこう': 4,
#    '学習装置': 1,
#    'あなぬけのヒモ': 1},
#   'supporters': {'博士の研究': 4, 'マリィ': 4, 'ボスの指令': 3},
#   'stadiums': {'頂への雪道': 1},
#   'energies': {'ダブルターボエネルギー': 4, '基本鋼エネルギー': 12},
#   'rank': 15,
#   'num_players': 64,
#   'date': '2022年12月18日(日)',
#   'prefecture': '神奈川県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/88cK8x-S9PDon-4Yc88x',
#   'deck_code': '88cK8x-S9PDon-4Yc88x',
#   'pokemons': {'イベルタル\nS8a 013/028': 3,
#    'モルペコ\nS4a 243/190': 2,
#    'ミルタンク\nS9a 058/067': 2,
#    'ルージュラ\nS9a 027/067': 1,
#    'カビゴン\nS4 084/100': 1,
#    'マナフィ\nS9 031/100': 1,
#    'コオリッポ\nSI 123/414': 1,
#    'ナマコブシ\nS8 027/100': 1,
#    'かがやくジラーチ\nS11a 045/068': 1,
#    'ピジョットV\nS11 112/100': 1},
#   'tools': {'クイックボール': 4,
#    'ヒスイのヘビーボール': 1,
#    'バトルVIPパス': 1,
#    '回収ネット': 3,
#    'ツールスクラッパー': 1,
#    'クラッシュハンマー': 3,
#    'タフネスマント': 3,
#    'ビッグパラソル': 1,
#    'あなぬけのヒモ': 1,
#    '森の封印石': 1,
#    'ふつうのつりざお': 1},
#   'supporters': {'シロナの覇気': 2,
#    'マリィ': 3,
#    'カイ': 3,
#    'シマボシ': 1,
#    'ネズ': 1,
#    'アスナ': 1,
#    'カゲツ': 1,
#    'ボスの指令': 1},
#   'stadiums': {'ガラル鉱山': 4},
#   'energies': {'ツインエネルギー': 4, 'ダブルターボエネルギー': 3, 'ウォッシュ水エネルギー': 2},
#   'rank': 16,
#   'num_players': 64,
#   'date': '2022年12月18日(日)',
#   'prefecture': '神奈川県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/MREMyy-goCjQu-2yypXM',
#   'deck_code': 'MREMyy-goCjQu-2yypXM',
#   'pokemons': {'アローラロコンV\nS11a 022/068': 1,
#    'アローラロコンVSTAR\nS11a 023/068': 1,
#    'コオリッポ\nSI 123/414': 1,
#    'ドラピオンV\nS12a 085/172': 1,
#    'メッソン\nSI 116/414': 4,
#    'ジメレオン\nS1W 018/060': 3,
#    'インテレオン\nS1W 019/060': 2,
#    'インテレオン\nSI 118/414': 1,
#    'ユキハミ\nS4a 047/190': 2,
#    'モスノウ\nS8b 040/184': 2,
#    'フリーザー\nS11a 024/068': 2,
#    'マナフィ\nS12a 029/172': 1,
#    'かがやくゲッコウガ\nS12a 033/172': 1},
#   'tools': {'クイックボール': 2,
#    'レベルボール': 4,
#    'しんかのおこう': 2,
#    'ふうせん': 1,
#    '回収ネット': 4,
#    'たっぷりバケツ': 3,
#    'きんきゅうゼリー': 2,
#    'ふしぎなアメ': 1,
#    'バトルVIPパス': 1},
#   'supporters': {'マリィ': 1, 'キバナ': 1, 'ボスの指令': 2, 'カイ': 4, 'ルリナ': 2},
#   'stadiums': {'トレーニングコート': 1},
#   'energies': {'ウォッシュ水エネルギー': 1, '基本水エネルギー': 6},
#   'rank': 5,
#   'num_players': 64,
#   'date': '2022年12月18日(日)',
#   'prefecture': '宮崎県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/xaxxaD-pMWxoP-cG88x8',
#   'deck_code': 'xaxxaD-pMWxoP-cG88x8',
#   'pokemons': {'カイオーガ\nS8a 007/028': 3,
#    'マナフィ\nS9 031/100': 1,
#    'フリージオ\nSI 106/414': 2,
#    'メタモン\nS10b 053/071': 2,
#    'ネオラントV\nSPD 002/020': 1,
#    'ヒスイ バスラオ\nS9a 023/067': 2,
#    'ヒスイ イダイトウ\nS10a 013/071': 1,
#    'かがやくカメックス\nS10b 018/071': 1,
#    'イベルタル\nS8a 013/028': 1,
#    'フリーザー\nS11a 024/068': 1},
#   'tools': {'ポケモンいれかえ': 1,
#    'バトルVIPパス': 1,
#    'やまびこホーン': 1,
#    'ハイパーボール': 3,
#    'レスキューキャリー': 1,
#    'トイキャッチャー': 2,
#    'キャンセルコロン': 1},
#   'supporters': {'カイ': 2, 'ネジキ': 1, 'ピオニー': 1},
#   'stadiums': {},
#   'energies': {'基本水エネルギー': 31},
#   'rank': 9,
#   'num_players': 80,
#   'date': '2022年12月18日(日)',
#   'prefecture': '大阪府'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/3yEEMU-f74Nba-MM2pyy',
#   'deck_code': '3yEEMU-f74Nba-MM2pyy',
#   'pokemons': {'れんげきウーラオスVMAX\nS5R 051/070': 2,
#    'れんげきウーラオスV\nS5R 077/070': 2,
#    'チャーレムV\nS7R 072/067': 1,
#    'ドラピオンV\nS11 107/100': 1,
#    'ライコウV\nSI 137/414': 2,
#    'インテレオン\nS5a 018/070': 2,
#    'インテレオン\nS4a 226/190': 1,
#    'ジメレオン\nS4a 225/190': 3,
#    'メッソン\nS5a 016/070': 4,
#    'マナフィ\nS9 031/100': 1,
#    'かがやくリザードン\nS12a 015/172': 1},
#   'tools': {'クイックボール': 4,
#    'レベルボール': 3,
#    'しんかのおこう': 3,
#    '回収ネット': 2,
#    'あなぬけのヒモ': 1,
#    'エネルギー転送': 2,
#    'ふつうのつりざお': 1,
#    'キャンセルコロン': 1,
#    'トイキャッチャー': 1,
#    'こだわりベルト': 2,
#    '空の封印石': 1,
#    '森の封印石': 1},
#   'supporters': {'博士の研究': 3, 'カイ': 1, 'ツツジ': 1, 'キバナ': 2, 'ボスの指令': 1},
#   'stadiums': {'みずの塔': 2},
#   'energies': {'基本闘エネルギー': 2, '基本雷エネルギー': 2, '基本炎エネルギー': 1, 'れんげきエネルギー': 3},
#   'rank': 15,
#   'num_players': 80,
#   'date': '2022年12月18日(日)',
#   'prefecture': '大阪府'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/kV5VVF-H5N0jt-f1kbkV',
#   'deck_code': 'kV5VVF-H5N0jt-f1kbkV',
#   'pokemons': {'メッソン\nSI 116/414': 4,
#    'ジメレオン\nS4a 040/190': 3,
#    'インテレオン\nS4a 041/190': 2,
#    'インテレオン\nS8b 038/184': 1,
#    'ユキハミ\nS4a 047/190': 2,
#    'モスノウ\nS8b 040/184': 2,
#    'かがやくゲッコウガ\nS12a 033/172': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'フリーザー\nS11a 024/068': 1,
#    'エンペルトV\nSI 100/414': 2,
#    'ケケンカニV\nSI 112/414': 1,
#    'ネオラントV\nSPD 002/020': 1,
#    'ドラピオンV\nS11 066/100': 1},
#   'tools': {'クイックボール': 3,
#    'レベルボール': 3,
#    'しんかのおこう': 2,
#    'バトルVIPパス': 1,
#    'ヒスイのヘビーボール': 1,
#    'たっぷりバケツ': 3,
#    '回収ネット': 3,
#    '空の封印石': 1,
#    'ともだちてちょう': 1,
#    'きんきゅうゼリー': 1,
#    'ふうせん': 1},
#   'supporters': {'カイ': 4, 'ルリナ': 1, 'ツツジ': 1, 'キバナ': 1, 'ボスの指令': 1},
#   'stadiums': {'トレーニングコート': 2},
#   'energies': {'基本水エネルギー': 8},
#   'rank': 6,
#   'num_players': 32,
#   'date': '2022年12月18日(日)',
#   'prefecture': '愛媛県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/G4D8Y8-ztJiGo-x888xG',
#   'deck_code': 'G4D8Y8-ztJiGo-x888xG',
#   'pokemons': {'ライコウV\nSI 137/414': 1,
#    'ガラル サンダーV\nS8b 084/184': 1,
#    'ゼラオラ\nS3a 021/076': 1,
#    'ガラル ファイヤー\nS7D 026/067': 1,
#    'メッソン\nS8b 036/184': 4,
#    'ジメレオン\nS4a 040/190': 3,
#    'インテレオン\nS4a 041/190': 2,
#    'インテレオン\nS8b 038/184': 1,
#    'マナフィ\nS9 031/100': 1,
#    'かがやくリザードン\nS10b 011/071': 1},
#   'tools': {'クイックボール': 4,
#    'レベルボール': 4,
#    'ヒスイのヘビーボール': 1,
#    'しんかのおこう': 3,
#    '回収ネット': 4,
#    'エネルギー転送': 2,
#    'ふしぎなアメ': 2,
#    'エネルギーつけかえ': 1,
#    'エネルギー回収': 1,
#    'あなぬけのヒモ': 1,
#    'こだわりベルト': 1,
#    'タフネスマント': 1,
#    'ロストスイーパー': 1,
#    'ともだちてちょう': 1,
#    '空の封印石': 1},
#   'supporters': {'キバナ': 2,
#    'セイボリー': 1,
#    'ボスの指令': 1,
#    'カイ': 1,
#    'クララ': 1,
#    'セレナ': 1},
#   'stadiums': {'トレーニングコート': 1},
#   'energies': {'基本悪エネルギー': 3,
#    '基本雷エネルギー': 1,
#    '基本水エネルギー': 2,
#    '基本闘エネルギー': 1,
#    '基本炎エネルギー': 1},
#   'rank': 3,
#   'num_players': 70,
#   'date': '2022年12月17日(土)',
#   'prefecture': '埼玉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/x8D8x4-GF2t5x-x8x8xx',
#   'deck_code': 'x8D8x4-GF2t5x-x8x8xx',
#   'pokemons': {'アルセウスVSTAR\nS12a 127/172': 3,
#    'アルセウスV\nS-P 267/S-P': 3,
#    'イベルタル\nS8a 013/028': 4,
#    'カビゴン\nS8b 126/184': 4,
#    'ヤレユータン\nS8b 212/184': 1,
#    'ノコッチ\nS12a 118/172': 1,
#    'かがやくサーナイト\nS12a 055/172': 1,
#    'ドラピオンV\nS12a 085/172': 2},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'ポケモンいれかえ': 1,
#    'あなぬけのヒモ': 1,
#    '回収ネット': 2,
#    '大きなおまもり': 2,
#    'ロストスイーパー': 1},
#   'supporters': {'博士の研究': 3,
#    'マリィ': 2,
#    'ボスの指令': 3,
#    'キバナ': 1,
#    'チェレンの気くばり': 2,
#    'カゲツ': 1,
#    'クララ': 1},
#   'stadiums': {'崩れたスタジアム': 1},
#   'energies': {'ダブルターボエネルギー': 4, 'ツインエネルギー': 2, '基本悪エネルギー': 6},
#   'rank': 8,
#   'num_players': 70,
#   'date': '2022年12月15日(木)',
#   'prefecture': '東京都'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/8G8YJc-kDyhEW-xxc8D8',
#   'deck_code': '8G8YJc-kDyhEW-xxc8D8',
#   'pokemons': {'メタモン\nS12a 117/172': 4,
#    'ヤレユータン\nS4a 297/190': 1,
#    'かがやくフシギバナ\nS10b 004/071': 1,
#    'ルージュラ\nS9a 027/067': 2,
#    'イベルタル\nS8a 013/028': 2,
#    'マナフィ\nS9 031/100': 1,
#    'メグロコ\nS4 070/100': 1,
#    'コオリッポ\nSI 123/414': 1,
#    'モルペコ\nS4a 062/190': 1,
#    'レジエレキ\nS12a 045/172': 1},
#   'tools': {'回収ネット': 3,
#    'トレッキングシューズ': 3,
#    'ともだちてちょう': 2,
#    'クイックボール': 4,
#    'レベルボール': 2,
#    'ハイパーボール': 2,
#    'ヒスイのヘビーボール': 1,
#    'レスキューキャリー': 1,
#    'ビッグパラソル': 1},
#   'supporters': {'博士の研究': 4,
#    'シマボシ': 2,
#    'カゲツ': 2,
#    '野盗三姉妹': 1,
#    'オニオン': 1,
#    'シャクヤ': 1,
#    'セレナ': 1},
#   'stadiums': {'ガラル鉱山': 3, '頂への雪道': 1},
#   'energies': {'ツインエネルギー': 3,
#    'ダブルターボエネルギー': 4,
#    'ウォッシュ水エネルギー': 2,
#    '基本水エネルギー': 1},
#   'rank': 9,
#   'num_players': 126,
#   'date': '2022年12月15日(木)',
#   'prefecture': '神奈川県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/VVkv5F-MzKTTO-kFVVkV',
#   'deck_code': 'VVkv5F-MzKTTO-kFVVkV',
#   'pokemons': {'オムスターV\nS12 018/098': 2,
#    'ネオラントV\nSPD 002/020': 2,
#    'ドラピオンV\nS11 066/100': 1,
#    'アーケオス\nS12 083/098': 3,
#    'アーケン\nS12 082/098': 3,
#    'かがやくリザードン\nS10b 011/071': 1,
#    'イベルタル\nS4a 117/190': 1,
#    'カイオーガ\nS4a 036/190': 1,
#    'ザマゼンタ\nS11a 053/068': 1,
#    'カプ・コケコ\nS4a 053/190': 1,
#    'ヤレユータン\nS8b 129/184': 1,
#    'マナフィ\nS9 031/100': 1},
#   'tools': {'クイックボール': 4,
#    'しんかのおこう': 3,
#    'ヒスイのヘビーボール': 1,
#    'ポケモンいれかえ': 1,
#    'あなぬけのヒモ': 1,
#    'ロストスイーパー': 1,
#    '森の封印石': 2,
#    'こだわりベルト': 2,
#    'ふうせん': 1},
#   'supporters': {'カイ': 3, 'マリィ': 3, 'セレナ': 2, 'ボスの指令': 1, 'ネジキ': 1},
#   'stadiums': {'崩れたスタジアム': 1},
#   'energies': {'オーロラエネルギー': 4,
#    'ギフトエネルギー': 4,
#    'ハイド悪エネルギー': 1,
#    'スピード雷エネルギー': 1,
#    'ウォッシュ水エネルギー': 1,
#    'コーティング鋼エネルギー': 1,
#    'ヒート炎エネルギー': 1,
#    'ツインエネルギー': 1,
#    'ダブルターボエネルギー': 1},
#   'rank': 11,
#   'num_players': 48,
#   'date': '2022年12月15日(木)',
#   'prefecture': '大阪府'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/XXyyMy-tHiZcw-yRyXMy',
#   'deck_code': 'XXyyMy-tHiZcw-yRyXMy',
#   'pokemons': {'ガラル ジグザグマ\nS4a 277/190': 4,
#    'ガラル マッスグマ\nSI 265/414': 1,
#    'ガラル タチフサグマ\nS8 061/100': 3,
#    'ガラル タチフサグマ\nS8b 207/184': 1,
#    'メッソン\nSI 116/414': 4,
#    'ジメレオン\nS4a 225/190': 3,
#    'インテレオン\nS4a 226/190': 2,
#    'インテレオン\nS5a 018/070': 1,
#    'かがやくリザードン\nS10b 011/071': 1,
#    'マナフィ\nS9 031/100': 1},
#   'tools': {'クイックボール': 2,
#    'レベルボール': 4,
#    'しんかのおこう': 4,
#    'ふしぎなアメ': 4,
#    '回収ネット': 4,
#    'エネルギー転送': 1,
#    'ヒスイのヘビーボール': 1,
#    'レスキューキャリー': 1,
#    'こだわりベルト': 1},
#   'supporters': {'クララ': 2,
#    'キバナ': 2,
#    'マリィ': 1,
#    'ヒナツ': 1,
#    'ペリーラ': 1,
#    'ネズ': 1,
#    'ボスの指令': 1},
#   'stadiums': {'シンオウ神殿': 1},
#   'energies': {'基本悪エネルギー': 4, '基本水エネルギー': 1, '基本炎エネルギー': 1, 'キャプチャーエネルギー': 1},
#   'rank': 14,
#   'num_players': 72,
#   'date': '2022年12月14日(水)',
#   'prefecture': '神奈川県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/nLLNnL-NreGjJ-nnQ9L9',
#   'deck_code': 'nLLNnL-NreGjJ-nnQ9L9',
#   'pokemons': {'アルセウスVSTAR\nS12a 127/172': 2,
#    'アルセウスV\nS12a 126/172': 2,
#    'メリープ\nSK 005/030': 3,
#    'モココ\nS12a 037/172': 3,
#    'ライチュウV\nS9 034/100': 2,
#    'ライコウV\nS12a 038/172': 2,
#    'ドラピオンV\nS12a 085/172': 1,
#    'ゼクロム\nS8b 195/184': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'クロバットV\nSLL 010/021': 1},
#   'tools': {'ふうせん': 3,
#    'ハイパーボール': 4,
#    'クイックボール': 4,
#    'こだわりベルト': 1,
#    'ふつうのつりざお': 1,
#    'ポケモンいれかえ': 2,
#    '大きなおまもり': 2},
#   'supporters': {'博士の研究': 4, 'マリィ': 3, 'ツツジ': 1, 'ボスの指令': 2},
#   'stadiums': {'頂への雪道': 2, 'ロストシティ': 1},
#   'energies': {'スピード雷エネルギー': 2, '基本雷エネルギー': 9, 'ダブルターボエネルギー': 1},
#   'rank': 15,
#   'num_players': 100,
#   'date': '2022年12月14日(水)',
#   'prefecture': '埼玉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/MMyyMy-zauVJV-MyRM2y',
#   'deck_code': 'MMyyMy-zauVJV-MyRM2y',
#   'pokemons': {'メタモン\nS10b 053/071': 4,
#    'ルージュラ\nS9a 027/067': 2,
#    'イベルタル\nS8a 013/028': 2,
#    'モルペコ\nS4a 062/190': 1,
#    'コオリッポ\nS7D 009/067': 1,
#    'レジエレキ\nS10D 022/067': 1,
#    'メグロコ\nS4 070/100': 1,
#    'マナフィ\nS9 031/100': 1,
#    'ヤレユータン\nS8b 129/184': 1,
#    'かがやくフシギバナ\nS10b 004/071': 1},
#   'tools': {'ヒスイのヘビーボール': 1,
#    'クイックボール': 4,
#    'レベルボール': 2,
#    'ハイパーボール': 2,
#    'レスキューキャリー': 1,
#    '回収ネット': 3,
#    'ビッグパラソル': 1,
#    'ともだちてちょう': 2,
#    'トレッキングシューズ': 3},
#   'supporters': {'博士の研究': 4,
#    'セレナ': 1,
#    'オニオン': 1,
#    'シマボシ': 2,
#    '野盗三姉妹': 2,
#    'カゲツ': 1,
#    'シャクヤ': 1},
#   'stadiums': {'頂への雪道': 1, 'ガラル鉱山': 3},
#   'energies': {'ダブルターボエネルギー': 4,
#    'ツインエネルギー': 3,
#    'ウォッシュ水エネルギー': 2,
#    '基本水エネルギー': 1},
#   'rank': 1,
#   'num_players': 126,
#   'date': '2022年12月13日(火)',
#   'prefecture': '神奈川県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/VFkkkk-F58yCI-kVFVFk',
#   'deck_code': 'VFkkkk-F58yCI-kVFVFk',
#   'pokemons': {'ドラパルトV\nS4a 088/190': 4,
#    'ドラパルトVMAX\nS4a 089/190': 3,
#    'ドラピオンV\nS12a 085/172': 1,
#    'メッソン\nSI 116/414': 3,
#    'ジメレオン\nS4a 040/190': 3,
#    'インテレオン\nSI 118/414': 2,
#    'インテレオン\nS4a 041/190': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'かがやくフーディン\nS11a 031/068': 1},
#   'tools': {'森の封印石': 1,
#    'ポケモンいれかえ': 1,
#    'あなぬけのヒモ': 2,
#    'レベルボール': 2,
#    '霧の水晶': 4,
#    'しんかのおこう': 4,
#    'ふつうのつりざお': 1,
#    'ツールスクラッパー': 1,
#    'こだわりベルト': 2,
#    '回収ネット': 2,
#    'クイックボール': 2},
#   'supporters': {'博士の研究': 3, 'ボスの指令': 2, 'マリィ': 3, 'ツツジ': 1},
#   'stadiums': {'頂への雪道': 2},
#   'energies': {'基本超エネルギー': 6, 'ホラー超エネルギー': 2},
#   'rank': 13,
#   'num_players': 48,
#   'date': '2022年12月12日(月)',
#   'prefecture': '大阪府'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/F1fkVF-xyM1uW-kkkFVv',
#   'deck_code': 'F1fkVF-xyM1uW-kkkFVv',
#   'pokemons': {'ケケンカニV\nSI 112/414': 1,
#    'メッソン\nSI 116/414': 4,
#    'ジメレオン\nS4a 040/190': 3,
#    'インテレオン\nS4a 041/190': 2,
#    'インテレオン\nSI 118/414': 1,
#    'ユキハミ\nS4a 047/190': 3,
#    'モスノウ\nS8b 040/184': 2,
#    'フリーザー\nS11a 024/068': 2,
#    'コオリッポ\nSI 123/414': 1,
#    'マナフィ\nS9 031/100': 1,
#    'かがやくゲッコウガ\nS9a 026/067': 1},
#   'tools': {'クイックボール': 2,
#    'レベルボール': 3,
#    'しんかのおこう': 2,
#    'たっぷりバケツ': 3,
#    '回収ネット': 4,
#    'ふしぎなアメ': 1,
#    'ヒスイのヘビーボール': 1,
#    'ともだちてちょう': 1,
#    'ふうせん': 1,
#    '空の封印石': 1},
#   'supporters': {'カイ': 4, 'ルリナ': 2, 'ボスの指令': 1, 'ツツジ': 1},
#   'stadiums': {'トレーニングコート': 2},
#   'energies': {'基本水エネルギー': 7, 'ウォッシュ水エネルギー': 2, 'キャプチャーエネルギー': 1},
#   'rank': 9,
#   'num_players': 126,
#   'date': '2022年12月08日(木)',
#   'prefecture': '神奈川県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/NnQPg6-oB1G4K-PnngLN',
#   'deck_code': 'NnQPg6-oB1G4K-PnngLN',
#   'pokemons': {'ゼクロム\nS8b 195/184': 2,
#    'メリープ\nSD 030/127': 4,
#    'モココ\nSI 135/414': 4,
#    'カビゴン\nS10a 058/071': 2,
#    'サンダー\nS10b 029/071': 1,
#    'ライコウV\nS12a 038/172': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'ビッパ\nS9 081/100': 1,
#    'ビーダル\nS9 082/100': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 3,
#    'レベルボール': 3,
#    'こだわりベルト': 2,
#    'ふうせん': 3,
#    '回収ネット': 3,
#    'ふつうのつりざお': 2},
#   'supporters': {'博士の研究': 4, 'マリィ': 3, 'セレナ': 2, 'ツツジ': 2},
#   'stadiums': {'頂への雪道': 2},
#   'energies': {'基本雷エネルギー': 8, 'ツインエネルギー': 2},
#   'rank': 9,
#   'num_players': 70,
#   'date': '2022年12月07日(水)',
#   'prefecture': '奈良県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/yypyXM-Mloa3j-yyXppy',
#   'deck_code': 'yypyXM-Mloa3j-yyXppy',
#   'pokemons': {'フーパ\nS3 061/100': 2,
#    'ガラル ファイヤー\nS7D 026/067': 2,
#    'ヤミラミV\nS1H 064/060': 1,
#    'ゼラオラ\nS3a 021/076': 2,
#    'インテレオン\nS5a 018/070': 2,
#    'インテレオン\nS4a 041/190': 1,
#    'ジメレオン\nS1W 018/060': 3,
#    'メッソン\nSI 116/414': 4,
#    'マナフィ\nS12a 029/172': 1},
#   'tools': {'クイックボール': 4,
#    'レベルボール': 2,
#    'しんかのおこう': 2,
#    'ヒスイのヘビーボール': 1,
#    'バトルVIPパス': 1,
#    'ふしぎなアメ': 1,
#    '回収ネット': 3,
#    'エネルギー転送': 3,
#    'エネルギーつけかえ': 1,
#    'こだわりベルト': 2,
#    '空の封印石': 1},
#   'supporters': {'カイ': 4,
#    '博士の研究': 1,
#    'マリィ': 1,
#    'ボスの指令': 2,
#    'キバナ': 2,
#    'クララ': 2},
#   'stadiums': {'トレーニングコート': 2},
#   'energies': {'基本悪エネルギー': 5, '基本雷エネルギー': 1, '基本水エネルギー': 1},
#   'rank': 13,
#   'num_players': 52,
#   'date': '2022年12月04日(日)',
#   'prefecture': '東京都'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/gHLnn9-MI1XdC-NLngnH',
#   'deck_code': 'gHLnn9-MI1XdC-NLngnH',
#   'pokemons': {'イベルタル\nS8a 013/028': 4,
#    'カビゴン\nS8b 126/184': 3,
#    'ミルタンク\nS12a 119/172': 2,
#    'コオリッポ\nSI 123/414': 1,
#    'かがやくサーナイト\nS12a 055/172': 1,
#    'ピジョットV\nS11 082/100': 1,
#    'ワタシラガV\nS4a 016/190': 1,
#    'こくばバドレックスV\nSI 203/414': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'ナマコブシ\nS8 027/100': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 2,
#    'ヒスイのヘビーボール': 1,
#    '回収ネット': 3,
#    'トレッキングシューズ': 1,
#    'ふつうのつりざお': 1,
#    'クラッシュハンマー': 2,
#    'ともだちてちょう': 1,
#    '森の封印石': 1,
#    'タフネスマント': 2},
#   'supporters': {'アクロマの実験': 3,
#    'とりつかい': 2,
#    'シバ': 1,
#    '博士の研究': 1,
#    'ネズ': 1,
#    'カイ': 1,
#    'カゲツ': 1,
#    'アスナ': 1,
#    'ボスの指令': 1,
#    'シャクヤ': 1,
#    'ハマナのバックアップ': 1},
#   'stadiums': {'ガラル鉱山': 2},
#   'energies': {'ダブルターボエネルギー': 4,
#    'ツインエネルギー': 3,
#    'ウォッシュ水エネルギー': 1,
#    'オーロラエネルギー': 2},
#   'rank': 1,
#   'num_players': 60,
#   'date': '2022年12月04日(日)',
#   'prefecture': '沖縄県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/nNnQLn-Fv4SZY-LL6nLg',
#   'deck_code': 'nNnQLn-Fv4SZY-LL6nLg',
#   'pokemons': {'アイアント\nS5I 003/070': 4,
#    'イベルタル\nS8a 013/028': 2,
#    'コオリッポ\nS7D 009/067': 2,
#    'モルペコ\nS4a 243/190': 1,
#    'ミルタンク\nS12a 119/172': 1,
#    'メタモン\nS12a 117/172': 1,
#    'カビゴン\nS8b 126/184': 1,
#    'チラチーノ\nS4a 143/190': 3,
#    'チラーミィ\nS9 085/100': 3,
#    'マナフィ\nS12a 029/172': 1},
#   'tools': {'クイックボール': 4,
#    'レベルボール': 3,
#    'ヒスイのヘビーボール': 1,
#    '回収ネット': 3,
#    'レスキューキャリー': 3,
#    'ふつうのつりざお': 1,
#    'エネくじ': 2,
#    'やまびこホーン': 1},
#   'supporters': {'シバ': 4, 'ボスの指令': 4, 'セレナ': 2},
#   'stadiums': {'ガラル鉱山': 4},
#   'energies': {'ツインエネルギー': 4, 'ダブルターボエネルギー': 3, 'ウォッシュ水エネルギー': 2},
#   'rank': 2,
#   'num_players': 64,
#   'date': '2022年12月04日(日)',
#   'prefecture': '大阪府'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/MyypXM-Xw0I99-Ep2Myy',
#   'deck_code': 'MyypXM-Xw0I99-Ep2Myy',
#   'pokemons': {'アーマーガアV\nS5R 078/070': 2,
#    'アーマーガアVMAX\nS8b 249/184': 2,
#    'アルセウスV\nS-P 267/S-P': 4,
#    'アルセウスVSTAR\nS9 084/100': 3,
#    'かがやくリザードン\nS10b 011/071': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'こだわりベルト': 2,
#    '大きなおまもり': 1,
#    'ポケモンいれかえ': 1,
#    'あなぬけのヒモ': 1,
#    'ともだちてちょう': 1,
#    'ポケギア3.0': 1,
#    'エネくじ': 1,
#    'やまびこホーン': 1,
#    'キャンセルコロン': 1,
#    'ロストスイーパー': 1},
#   'supporters': {'マリィ': 4,
#    'セレナ': 3,
#    'ボスの指令': 2,
#    '博士の研究': 1,
#    'セイボリー': 1,
#    'チェレンの気くばり': 1},
#   'stadiums': {'ロストシティ': 1, '崩れたスタジアム': 1, '頂への雪道': 1},
#   'energies': {'ダブルターボエネルギー': 4,
#    'キャプチャーエネルギー': 1,
#    'パワフル無色エネルギー': 1,
#    'Vガードエネルギー': 1,
#    '基本鋼エネルギー': 5,
#    '基本炎エネルギー': 2},
#   'rank': 12,
#   'num_players': 48,
#   'date': '2022年12月03日(土)',
#   'prefecture': '東京都'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/888x88-zTryM3-8cDDc8',
#   'deck_code': '888x88-zTryM3-8cDDc8',
#   'pokemons': {'アルセウスV\nS9 111/100': 1,
#    'アルセウスV\nS9 083/100': 3,
#    'アルセウスVSTAR\nS9 084/100': 2,
#    'ラプラスV\nS1W 014/060': 2,
#    'ラプラスVMAX\nS1W 015/060': 2,
#    'ビッパ\nS9 081/100': 2,
#    'ビーダル\nS9 082/100': 2,
#    'かがやくサーナイト\nS10a 027/071': 1,
#    'コオリッポ\nSI 123/414': 1,
#    'クロバットV\nSK 008/030': 1},
#   'tools': {'ハイパーボール': 4,
#    'クイックボール': 4,
#    'しんかのおこう': 4,
#    'ポケモンいれかえ': 1,
#    'ふつうのつりざお': 1,
#    'あなぬけのヒモ': 1,
#    'こだわりベルト': 1,
#    '大きなおまもり': 1},
#   'supporters': {'チェレンの気くばり': 1, 'メロン': 1, 'マリィ': 4, 'ボスの指令': 2},
#   'stadiums': {'エイチ湖': 2},
#   'energies': {'ウォッシュ水エネルギー': 1, '基本水エネルギー': 10, 'ダブルターボエネルギー': 4},
#   'rank': 6,
#   'num_players': 48,
#   'date': '2022年12月03日(土)',
#   'prefecture': '茨城県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/Dxx88c-i4Tva5-D48884',
#   'deck_code': 'Dxx88c-i4Tva5-D48884',
#   'pokemons': {'リオル\nS12a 076/172': 4,
#    'ルカリオ\nS9 055/100': 4,
#    'ヤジロン\nS12 047/098': 4,
#    'ネンドール\nS12 048/098': 4,
#    'シンボラー\nS12 039/098': 4,
#    'ビッパ\nS9 081/100': 2,
#    'ビーダル\nS9 082/100': 2,
#    'ミルタンク\nS12a 119/172': 1,
#    'マナフィ\nS12a 029/172': 1,
#    'ガラル サンダーV\nS8b 084/184': 1},
#   'tools': {'レベルボール': 3,
#    'キャプチャーアロマ': 1,
#    'しんかのおこう': 4,
#    'ハイパーボール': 2,
#    'ポケモンキャッチャー': 3,
#    'こだわりベルト': 2,
#    'ポケモンいれかえ': 2,
#    'ふつうのつりざお': 1,
#    '大地の封印石': 1},
#   'supporters': {'ザクロ': 1},
#   'stadiums': {'頂への雪道': 1, 'ポケストップ': 2},
#   'energies': {'基本闘エネルギー': 8, 'ストーン闘エネルギー': 2},
#   'rank': 11,
#   'num_players': 48,
#   'date': '2022年12月03日(土)',
#   'prefecture': '茨城県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/xcD8x8-z79fiZ-Y8cD88',
#   'deck_code': 'xcD8x8-z79fiZ-Y8cD88',
#   'pokemons': {'メッソン\nS5a 016/070': 4,
#    'ジメレオン\nS4a 225/190': 3,
#    'インテレオン\nS4a 226/190': 2,
#    'マナフィ\nS9 031/100': 1,
#    'かがやくリザードン\nS10b 011/071': 1,
#    'ドラピオンV\nS11 066/100': 1,
#    'コオリッポ\nSI 123/414': 1,
#    'ミュウ\nS8a 002/028': 1,
#    'インテレオン\nS5a 018/070': 1,
#    'カビゴン\nS10a 058/071': 1,
# ...
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/yMySM2-rwnaqC-3yMpy2',
#   'deck_code': 'yMySM2-rwnaqC-3yMpy2',
#   'pokemons': {'アローラロコンV\nS11a 022/068': 4, 'アローラロコンVSTAR\nS11a 023/068': 4},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'キャプチャーアロマ': 2,
#    'たっぷりバケツ': 2,
#    'モーモーチーズ': 1,
#    'やまびこホーン': 1,
#    'ツールスクラッパー': 1,
#    'クラッシュハンマー': 4,
#    'ポケギア3.0': 3,
#    'ビッグパラソル': 4},
#   'supporters': {'メロン': 4, 'マリィ': 3, '博士の研究': 2, 'ボスの指令': 2},
#   'stadiums': {'エイチ湖': 2, 'ロストシティ': 1},
#   'energies': {'ダブルターボエネルギー': 4, '基本水エネルギー': 8},
#   'rank': 3,
#   'num_players': 64,
#   'date': '2022年11月20日(日)',
#   'prefecture': '東京都'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/pUypMy-rphGgx-RMSySp',
#   'deck_code': 'pUypMy-rphGgx-RMSySp',
#   'pokemons': {'アイアント\nS5I 003/070': 4,
#    'ビッパ\nS9 081/100': 2,
#    'ビーダル\nS9 082/100': 3,
#    'カビゴン\nS8b 126/184': 1,
#    'マナフィ\nS9 031/100': 1},
#   'tools': {'クイックボール': 4,
#    'レベルボール': 4,
#    'ハイパーボール': 4,
#    'ヒスイのヘビーボール': 2,
#    'レスキューキャリー': 3,
#    'トレッキングシューズ': 4,
#    'ウッウロボ': 2,
#    'おうえんYホーン': 2,
#    'ともだちてちょう': 2,
#    '回収ネット': 2,
#    'ロストスイーパー': 1,
#    'のろいのスコップ': 4,
#    'ふうせん': 1},
#   'supporters': {'野盗三姉妹': 4, 'シマボシ': 1},
#   'stadiums': {'ポケストップ': 2},
#   'energies': {'ツインエネルギー': 3, 'ダブルターボエネルギー': 4},
#   'rank': 5,
#   'num_players': 32,
#   'date': '2022年11月20日(日)',
#   'prefecture': '徳島県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/PHLnnP-PUyQE9-HLLngN',
#   'deck_code': 'PHLnnP-PUyQE9-HLLngN',
#   'pokemons': {'ヒードランVMAX\nS10P 015/067': 1,
#    'ヒードランV\nS10P 072/067': 1,
#    'かがやくヒードラン\nS9a 011/067': 1,
#    'エンテイV\nSI 056/414': 2,
#    'ライコウV\nSI 137/414': 1,
#    'ガラル サンダーV\nSI 217/414': 1,
#    'エルレイド\nS9a 034/067': 1,
#    'キルリア\nS11a 037/068': 2,
#    'ラルトス\nS11a 036/068': 3,
#    'マナフィ\nS9 031/100': 1,
#    'クロバットV\nSLD 001/020': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 3,
#    'ヒスイのヘビーボール': 1,
#    'しんかのおこう': 1,
#    'こだわりベルト': 1,
#    'ふうせん': 2,
#    '森の封印石': 2,
#    'タフネスマント': 1,
#    'ポケモンいれかえ': 1,
#    'あなぬけのヒモ': 1,
#    'ふつうのつりざお': 1,
#    'ロストスイーパー': 1,
#    'ダメージポンプ': 1,
#    'エネルギーつけかえ': 1},
#   'supporters': {'博士の研究': 3,
#    'マリィ': 2,
#    'ボスの指令': 2,
#    'キバナ': 1,
#    'セレナ': 1,
#    'ツツジ': 1},
#   'stadiums': {'マグマの滝壺': 4},
#   'energies': {'ヒート炎エネルギー': 2, '基本雷エネルギー': 1, '基本闘エネルギー': 1, '基本炎エネルギー': 6},
#   'rank': 3,
#   'num_players': 66,
#   'date': '2022年11月19日(土)',
#   'prefecture': '栃木県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/gLnnNi-5v8dXm-PLnNHL',
#   'deck_code': 'gLnnNi-5v8dXm-PLnNHL',
#   'pokemons': {'アイアント\nS5I 003/070': 4,
#    'マナフィ\nS9 031/100': 1,
#    'イベルタル\nS8a 013/028': 1,
#    'メタモン\nS10b 053/071': 1,
#    'ビッパ\nS9 081/100': 2,
#    'ビーダル\nS9 082/100': 3,
#    'ルージュラ\nS9a 027/067': 1,
#    'かがやくジラーチ\nS11a 045/068': 1},
#   'tools': {'レベルボール': 4,
#    'クイックボール': 3,
#    'ヒスイのヘビーボール': 2,
#    'おうえんYホーン': 2,
#    'レスキューキャリー': 4,
#    'ともだちてちょう': 1,
#    'ふうせん': 2,
#    'のろいのスコップ': 3,
#    'ハイパーボール': 4},
#   'supporters': {'ボスの指令': 1,
#    'とりつかい': 1,
#    'シバ': 1,
#    'シャクヤ': 1,
#    'セレナ': 1,
#    '野盗三姉妹': 2,
#    'カゲツ': 1,
#    'ハマナのバックアップ': 1},
#   'stadiums': {'ポケストップ': 4},
#   'energies': {'ツインエネルギー': 4, 'ダブルターボエネルギー': 4},
#   'rank': 5,
#   'num_players': 80,
#   'date': '2022年11月18日(金)',
#   'prefecture': '大阪府'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/kbVVbk-Jg0nYE-FkVV1F',
#   'deck_code': 'kbVVbk-Jg0nYE-FkVV1F',
#   'pokemons': {'ミルタンク\nS9a 058/067': 2,
#    'モルペコ\nS4a 243/190': 2,
#    'イベルタル\nS8a 013/028': 3,
#    'マナフィ\nS9 031/100': 1,
#    'かがやくジラーチ\nS11a 045/068': 1,
#    'ピジョットV\nS11 112/100': 1,
#    'パッチール\nS11 086/100': 1,
#    'カビゴン\nS10b 056/071': 1,
#    'ミカルゲ\nS8b 107/184': 1},
#   'tools': {'クイックボール': 4,
#    'トレッキングシューズ': 3,
#    'あなぬけのヒモ': 1,
#    'タフネスマント': 2,
#    'いれかえカート': 4,
#    'おうえんYホーン': 3},
#   'supporters': {'ボスの指令': 1,
#    'マリィ': 4,
#    'セレナ': 2,
#    'ネジキ': 2,
#    'ネズ': 1,
#    'アクロマの実験': 2,
#    'ふりそで': 1,
#    'シバ': 1},
#   'stadiums': {'ガラル鉱山': 4},
#   'energies': {'ツインエネルギー': 4,
#    'ダブルターボエネルギー': 4,
#    'キャプチャーエネルギー': 2,
#    'ギフトエネルギー': 2},
#   'rank': 8,
#   'num_players': 72,
#   'date': '2022年11月16日(水)',
#   'prefecture': '神奈川県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/2SpyMy-7rlNTJ-XMSRpM',
#   'deck_code': '2SpyMy-7rlNTJ-XMSRpM',
#   'pokemons': {'ジャローダVSTAR\nS11a 006/068': 1,
#    'ジャローダV\nS11a 075/068': 1,
#    'ドラピオンV\nS11 066/100': 1,
#    'ミルタンク\nS9a 058/067': 2,
#    'モルペコ\nS4a 062/190': 1,
#    'マナフィ\nS9 031/100': 1,
#    'ヤレユータン\nS8b 129/184': 1,
#    'カビゴン\nS8b 126/184': 1,
#    'イベルタル\nS8a 013/028': 4,
#    'かがやくリザードン\nS10b 011/071': 1,
#    'コオリッポ\nS7D 009/067': 1,
#    'ツボツボ\nS3a 036/076': 1},
#   'tools': {'クイックボール': 4,
#    'ヒスイのヘビーボール': 1,
#    '回収ネット': 2,
#    'ふつうのつりざお': 1,
#    'ともだちてちょう': 1,
#    'ふうせん': 1,
#    'タフネスマント': 2},
#   'supporters': {'マリィ': 4,
#    'セレナ': 4,
#    '博士の研究': 3,
#    'セイボリー': 2,
#    'ハマナのバックアップ': 1,
#    'ボスの指令': 1},
#   'stadiums': {'頂への雪道': 1, '崩れたスタジアム': 2},
#   'energies': {'ダブルターボエネルギー': 4,
#    'キャプチャーエネルギー': 4,
#    'オーロラエネルギー': 3,
#    'ツインエネルギー': 2,
#    '基本炎エネルギー': 1},
#   'rank': 3,
#   'num_players': 100,
#   'date': '2022年11月13日(日)',
#   'prefecture': '神奈川県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/kVVkkk-ISutOP-kVkV1d',
#   'deck_code': 'kVVkkk-ISutOP-kVkV1d',
#   'pokemons': {'アイアント\nS5I 003/070': 4,
#    'イベルタル\nS8a 013/028': 2,
#    'ビッパ\nS9 081/100': 2,
#    'ビーダル\nS9 082/100': 2,
#    'マナフィ\nS9 031/100': 1,
#    'かがやくジラーチ\nS11a 045/068': 1},
#   'tools': {'クイックボール': 3,
#    'レベルボール': 2,
#    'ヒスイのヘビーボール': 2,
#    'ハイパーボール': 4,
#    'レスキューキャリー': 4,
#    'のろいのスコップ': 4,
#    'ふうせん': 2,
#    'バトルVIPパス': 4,
#    'ともだちてちょう': 1,
#    'おうえんYホーン': 2},
#   'supporters': {'野盗三姉妹': 3, 'シバ': 2, 'クララ': 1, 'ボスの指令': 1, 'セレナ': 1},
#   'stadiums': {'ポケストップ': 4},
#   'energies': {'ダブルターボエネルギー': 4, 'ツインエネルギー': 4},
#   'rank': 16,
#   'num_players': 34,
#   'date': '2022年11月13日(日)',
#   'prefecture': '北海道苫小牧市ときわ町6-23-30'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/cxD8K8-n8MuY4-x48D8x',
#   'deck_code': 'cxD8K8-n8MuY4-x48D8x',
#   'pokemons': {'セキタンザンV\nS3a 080/076': 3,
#    'セキタンザンVMAX\nS3a 043/076': 3,
#    'ヒスイ ウインディV\nS12 046/098': 2,
#    'ヤレユータン\nS8b 129/184': 3,
#    'クロバットV\nSLD 001/020': 1,
#    'チルット\nSD 078/127': 1,
#    'チルット\nS11a 056/068': 1,
#    'チルタリス\nS7D 040/067': 2,
#    'かがやくゲッコウガ\nS9a 026/067': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 3,
#    'しんかのおこう': 2,
#    'ポケモンいれかえ': 2,
#    'ビッグパラソル': 1,
#    'タフネスマント': 1,
#    '森の封印石': 1,
#    'やまびこホーン': 1,
#    'ともだちてちょう': 1},
#   'supporters': {'マリィ': 2,
#    '博士の研究': 2,
#    'セレナ': 1,
#    'モミ': 2,
#    'とりつかい': 1,
#    'ザクロ': 1,
#    'ボスの指令': 2},
#   'stadiums': {'トレーニングコート': 2, '崩れたスタジアム': 1},
#   'energies': {'ストーン闘エネルギー': 4, '基本闘エネルギー': 8, 'Vガードエネルギー': 1},
#   'rank': 4,
#   'num_players': 80,
#   'date': '2022年11月13日(日)',
#   'prefecture': '福岡県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/kkVfVf-zkFdJ3-fVk5kF',
#   'deck_code': 'kkVfVf-zkFdJ3-fVk5kF',
#   'pokemons': {'れんげきウーラオスV\nSI 248/414': 3,
#    'れんげきウーラオスVMAX\nS8b 095/184': 2,
#    'メッソン\nSI 116/414': 4,
#    'ジメレオン\nS4a 040/190': 3,
#    'インテレオン\nSI 118/414': 1,
#    'ナゲツケサル\nS8b 203/184': 1,
#    'クロバットV\nSLD 001/020': 1,
#    'ドラピオンV\nS11 107/100': 1,
#    'テッポウオ\nSI 089/414': 1,
#    'オクタン\nS8b 191/184': 1,
#    'マナフィ\nS9 031/100': 1,
#    'チャーレムV\nSI 221/414': 1,
#    'インテレオン\nS4a 041/190': 2},
#   'tools': {'クイックボール': 3,
#    'レベルボール': 3,
#    'しんかのおこう': 3,
#    '回収ネット': 3,
#    'エネルギー転送': 1,
#    'あなぬけのヒモ': 1,
#    'ヒスイのヘビーボール': 1,
#    'ふつうのつりざお': 1,
#    '望遠スコープ': 1,
#    '森の封印石': 1,
#    'こだわりベルト': 1},
#   'supporters': {'カイ': 2,
#    'モミ': 1,
#    'マリィ': 1,
#    'ボスの指令': 1,
#    'キバナ': 2,
#    'ツツジ': 1,
#    'ネジキ': 1,
#    '博士の研究': 1},
#   'stadiums': {'みずの塔': 2},
#   'energies': {'れんげきエネルギー': 4, '基本闘エネルギー': 3},
#   'rank': 6,
#   'num_players': 48,
#   'date': '2022年11月13日(日)',
#   'prefecture': '広島県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/yXyySX-FwqZKt-MyRpMM',
#   'deck_code': 'yXyySX-FwqZKt-MyRpMM',
#   'pokemons': {'アイアント\nS5I 003/070': 4,
#    'イベルタル\nS8a 013/028': 2,
#    'ビーダル\nS9 082/100': 3,
#    'ビッパ\nS9 081/100': 2,
#    'カビゴン\nS4 084/100': 2,
#    'マナフィ\nS9 031/100': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 3,
#    'レベルボール': 2,
#    'ヒスイのヘビーボール': 1,
#    'レスキューキャリー': 3,
#    '回収ネット': 2,
#    'クラッシュハンマー': 4,
#    'おうえんYホーン': 3,
#    'のろいのスコップ': 4,
#    'ふうせん': 2},
#   'supporters': {'野盗三姉妹': 4, 'アスナ': 1, 'シャクヤ': 1},
#   'stadiums': {'ポケストップ': 4},
#   'energies': {'ツインエネルギー': 4, 'ダブルターボエネルギー': 4},
#   'rank': 8,
#   'num_players': 32,
#   'date': '2022年11月13日(日)',
#   'prefecture': '東京都'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/yyESpM-hGjLRx-MMRyXS',
#   'deck_code': 'yyESpM-hGjLRx-MMRyXS',
#   'pokemons': {'イベルタル\nS8a 013/028': 4,
#    'ミルタンク\nS9a 058/067': 3,
#    'コオリッポ\nS7D 009/067': 1,
#    'アブリボン\nS6K 035/070': 1,
#    'アブリー\nS6K 034/070': 1,
#    'かがやくジラーチ\nS11a 045/068': 1,
#    'ナマコブシ\nS8 027/100': 1,
#    'ミュウ\nS8a 002/028': 1,
#    'ワタシラガV\nS2 097/096': 1,
#    'マナフィ\nS9 031/100': 1},
#   'tools': {'クイックボール': 4,
#    'レベルボール': 2,
#    'クラッシュハンマー': 4,
#    '回収ネット': 4,
#    'ポケギア3.0': 3,
#    'ビッグパラソル': 2,
#    'ヒスイのヘビーボール': 1,
#    'ツールスクラッパー': 1,
#    'ふつうのつりざお': 1,
#    'エネくじ': 1},
#   'supporters': {'カイ': 3,
#    'アスナ': 2,
#    'シバ': 2,
#    '博士の研究': 1,
#    'とりつかい': 1,
#    'ネズ': 1,
#    'アクロマの実験': 1,
#    'シャクヤ': 1},
#   'stadiums': {},
#   'energies': {'ダブルターボエネルギー': 4,
#    'ツインエネルギー': 3,
#    'ウォッシュ水エネルギー': 2,
#    '基本水エネルギー': 1},
#   'rank': 5,
#   'num_players': 32,
#   'date': '2022年11月12日(土)',
#   'prefecture': '茨城県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/gnPLnN-VYNiTF-ngLnLL',
#   'deck_code': 'gnPLnN-VYNiTF-ngLnLL',
#   'pokemons': {'アルセウスV\nS9 083/100': 4,
#    'アルセウスVSTAR\nS9 084/100': 2,
#    'ヒスイ ヌメルゴンV\nS10a 056/071': 2,
#    'ヒスイ ヌメルゴンVSTAR\nS10a 057/071': 2,
#    'かがやくサーナイト\nS10a 027/071': 1,
#    'イベルタル\nS8a 013/028': 1,
#    'ドラピオンV\nS11 107/100': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 3,
#    'しんかのおこう': 2,
#    '大きなおまもり': 1,
#    'ビッグパラソル': 1,
#    'すごいきずぐすり': 4,
#    'ポケモンいれかえ': 1,
#    'あなぬけのヒモ': 1},
#   'supporters': {'博士の研究': 1,
#    'マリィ': 2,
#    'アクロマの実験': 3,
#    'メロン': 3,
#    'ボスの指令': 1,
#    'セレナ': 1,
#    'ツツジ': 1},
#   'stadiums': {'頂への雪道': 1, 'エイチ湖': 3},
#   'energies': {'基本水エネルギー': 5, '基本鋼エネルギー': 4, 'ダブルターボエネルギー': 4, 'Vガードエネルギー': 1},
#   'rank': 14,
#   'num_players': 48,
#   'date': '2022年11月12日(土)',
#   'prefecture': '埼玉県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/MyyXMy-JxENGW-MMXpSM',
#   'deck_code': 'MyyXMy-JxENGW-MMXpSM',
#   'pokemons': {'ゲンガーV\nSI 253/414': 2,
#    'ゲンガーVMAX\nSGG 002/019': 2,
#    'アルセウスV\nS9 112/100': 4,
#    'アルセウスVSTAR\nS9 084/100': 2,
#    'ガラル ファイヤーV\nSI 254/414': 1,
#    'ガラル ファイヤー\nS7D 026/067': 1,
#    'ネオラントV\nS9 105/100': 2,
#    'クロバットV\nSLD 001/020': 1,
#    'かがやくサーナイト\nS10a 027/071': 1,
#    'ノコッチ\nS8 079/100': 1},
#   'tools': {'ハイパーボール': 4,
#    'クイックボール': 4,
#    'ポケモンいれかえ': 1,
#    'エネルギーつけかえ': 1,
#    'こだわりベルト': 2,
#    'ふつうのつりざお': 1,
#    'やまびこホーン': 1,
#    'あなぬけのヒモ': 1,
#    'ともだちてちょう': 1},
#   'supporters': {'ボスの指令': 1,
#    'セレナ': 1,
#    '博士の研究': 1,
#    'ネズ': 1,
#    'ネジキ': 1,
#    'チェレンの気くばり': 1,
#    'マリィ': 1,
#    'ダンデ': 1,
#    'ジャッジマン': 1,
#    'ツツジ': 1},
#   'stadiums': {'ロストシティ': 1, 'シンオウ神殿': 1, '頂への雪道': 1, '崩れたスタジアム': 1},
#   'energies': {'基本悪エネルギー': 8,
#    'ダブルターボエネルギー': 2,
#    'パワフル無色エネルギー': 1,
#    'いちげきエネルギー': 2},
#   'rank': 2,
#   'num_players': 32,
#   'date': '2022年11月12日(土)',
#   'prefecture': '大阪府'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/x8488x-x6GAvu-D8xDxc',
#   'deck_code': 'x8488x-x6GAvu-D8xDxc',
#   'pokemons': {'モルペコV\nS1H 019/060': 2,
#    'ディアンシー\nS9a 035/067': 4,
#    'メリープ\nS7R 026/067': 3,
#    'モココ\nS8b 052/184': 3,
#    'クワガノンV\nS2a 025/070': 1,
#    'ライコウV\nSI 137/414': 1,
#    'サンダー\nS10b 029/071': 2,
#    'マナフィ\nS9 031/100': 1,
#    'ネオラントV\nS9 030/100': 1,
#    'クロバットV\nSK 008/030': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 3,
#    'レベルボール': 3,
#    'ふうせん': 3,
#    'こだわりベルト': 2,
#    'レスキューキャリー': 1,
#    'ふつうのつりざお': 1,
#    'やまびこホーン': 1,
#    'あなぬけのヒモ': 1},
#   'supporters': {'マリィ': 3, '博士の研究': 3, 'セレナ': 2, 'ボスの指令': 1},
#   'stadiums': {'嵐の山脈': 2, '頂への雪道': 1},
#   'energies': {'スピード雷エネルギー': 2, '基本雷エネルギー': 8},
#   'rank': 9,
#   'num_players': 66,
#   'date': '2022年11月12日(土)',
#   'prefecture': '栃木県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/YxccGx-gbdDtU-8KxD88',
#   'deck_code': 'YxccGx-gbdDtU-8KxD88',
#   'pokemons': {'マナフィ\nS9 031/100': 2,
#    'メタモン\nS10b 053/071': 1,
#    'イベルタル\nS8a 013/028': 3,
#    'アイアント\nS5I 003/070': 4,
#    'かがやくジラーチ\nS11a 045/068': 1},
#   'tools': {'クイックボール': 3,
#    'おむかえちょうちん': 1,
#    'のろいのスコップ': 4,
#    'レベルボール': 4,
#    'レスキューキャリー': 3,
#    '回収ネット': 2,
#    'エネくじ': 2,
#    'おうえんYホーン': 3,
#    'ヒスイのヘビーボール': 1,
#    'クラッシュハンマー': 3,
#    'ポケモンいれかえ': 2},
#   'supporters': {'シバ': 4, 'ボスの指令': 3, 'セレナ': 1, '野盗三姉妹': 1},
#   'stadiums': {'ポケストップ': 4},
#   'energies': {'ダブルターボエネルギー': 4, 'ツインエネルギー': 4},
#   'rank': 13,
#   'num_players': 66,
#   'date': '2022年11月12日(土)',
#   'prefecture': '栃木県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/Jc8c8x-vzTf01-8axxYx',
#   'deck_code': 'Jc8c8x-vzTf01-8axxYx',
#   'pokemons': {'ダークライVSTAR\nSLD 008/020': 3,
#    'ダークライV\nSLD 007/020': 4,
#    'ガラル ファイヤーV\nS5a 045/070': 2,
#    'クロバットV\nS3 053/100': 2,
#    'かがやくゲッコウガ\nS9a 026/067': 1,
#    'フーパ\nS3 061/100': 1,
#    'ガラル ファイヤー\nS7D 026/067': 1,
#    'ガラル ジグザグマ\nS1H 033/060': 1},
#   'tools': {'クイックボール': 4,
#    'ハイパーボール': 4,
#    'トレッキングシューズ': 4,
#    'ダークパッチ': 4,
#    'こだわりベルト': 2,
#    'ポケモンいれかえ': 1,
#    'ふつうのつりざお': 1,
#    'エネルギー転送': 1,
#    'あなぬけのヒモ': 1},
#   'supporters': {'博士の研究': 4, 'セレナ': 2},
#   'stadiums': {'トレーニングコート': 1, 'ポケストップ': 2},
#   'energies': {'基本悪エネルギー': 12, 'ハイド悪エネルギー': 2},
#   'rank': 14,
#   'num_players': 48,
#   'date': '2022年11月12日(土)',
#   'prefecture': '茨城県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/4c8G48-uLcKSI-8xxxx8',
#   'deck_code': '4c8G48-uLcKSI-8xxxx8',
#   'pokemons': {'リザードンV\nS9 014/100': 2,
#    'リザードンVSTAR\nS9 015/100': 2,
#    'ビクティニV\nSA 003/023': 2,
#    'ビクティニVMAX\nSI 060/414': 2,
#    'かがやくリザードン\nS10b 011/071': 1,
#    'ギャロップ\nS12 011/098': 3,
#    'ポニータ\nS12 010/098': 3,
#    'ビーダル\nS9 082/100': 2,
#    'ビッパ\nS9 081/100': 2,
#    'クロバットV\nSLD 001/020': 1},
#   'tools': {'ハイパーボール': 4,
#    'クイックボール': 4,
#    'しんかのおこう': 3,
#    'バトルVIPパス': 3,
#    'こだわりベルト': 2,
#    'エネルギー回収': 1,
#    'ふうせん': 1,
#    'ふつうのつりざお': 1},
#   'supporters': {'セレナ': 3, 'ボスの指令': 2, '博士の研究': 2},
#   'stadiums': {'マグマの滝壺': 3},
#   'energies': {'基本炎エネルギー': 11},
#   'rank': 7,
#   'num_players': 32,
#   'date': '2022年11月12日(土)',
#   'prefecture': '東京都'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/VVvFkF-K6Q20g-VfVFFk',
#   'deck_code': 'VVvFkF-K6Q20g-VfVFFk',
#   'pokemons': {'クワガノンV\nS2a 025/070': 2,
#    'ライコウV\nSI 137/414': 1,
#    'ガラル ファイヤーV\nSI 254/414': 2,
#    'ガラル サンダーV\nSI 217/414': 1,
#    'ネオラントV\nS9 105/100': 1,
#    'クロバットV\nS-P 152/S-P': 1,
#    'かがやくゲッコウガ\nS9a 026/067': 1,
#    'サンダー\nS10b 029/071': 2,
#    'ミュウ\nSK 007/030': 3},
#   'tools': {'クイックボール': 4,
#    'バトルVIPパス': 3,
#    'ヒスイのヘビーボール': 1,
#    '回収ネット': 3,
#    'ふうせん': 1,
#    'いれかえカート': 1,
#    'あなぬけのヒモ': 1,
#    'ダークパッチ': 1,
#    'こだわりベルト': 1,
#    '森の封印石': 2,
#    'タフネスマント': 1,
#    'エネルギーつけかえ': 3,
#    'エネルギー転送': 2,
#    'ロストスイーパー': 1},
#   'supporters': {'ボスの指令': 3, 'マリィ': 2, 'ジャッジマン': 1, 'とりつかい': 1, 'キバナ': 1},
#   'stadiums': {'ポケストップ': 1, '頂への雪道': 1},
#   'energies': {'スピード雷エネルギー': 4, '基本雷エネルギー': 2, '基本悪エネルギー': 4, '基本闘エネルギー': 1},
#   'rank': 3,
#   'num_players': 100,
#   'date': '2022年11月10日(木)',
#   'prefecture': '神奈川県'},
#  {'deck_link': 'https://www.pokemon-card.com/deck/confirm.html/deckID/xcccc8-5wKu7R-xxYx8Y',
#   'deck_code': 'xcccc8-5wKu7R-xxYx8Y',
#   'pokemons': {'アルセウスVSTAR\nS9 084/100': 3,
#    'アルセウスV\nS9 083/100': 4,
#    'ライコウV\nSI 137/414': 2,
#    'リーフィアV\nSI 017/414': 1,
#    'ドラピオンV\nS11 066/100': 1,
#    'ヨノワール\nS8b 068/184': 2,
#    'ヨマワル\nS8b 066/184': 2,
#    'クロバットV\nSK 008/030': 1,
#    'ネオラントV\nSPZ 001/020': 1,
#    'バケッチャ\nS7D 016/067': 1},
#   'tools': {'バトルVIPパス': 4,
#    'クイックボール': 3,
#    'ハイパーボール': 4,
#    'しんかのおこう': 1,
#    'ふしぎなアメ': 2,
#    'こだわりベルト': 1,
#    'ふうせん': 1,
#    'あなぬけのヒモ': 1},
#   'supporters': {'博士の研究': 4,
#    'マリィ': 3,
#    'ボスの指令': 3,
#    'セレナ': 1,
#    'キバナ': 1,
#    'ツツジ': 1},
#   'stadiums': {},
#   'energies': {'基本雷エネルギー': 4,
#    '基本草エネルギー': 3,
#    'ダブルターボエネルギー': 2,
#    'キャプチャーエネルギー': 3},
#   'rank': 7,
#   'num_players': 100,
#   'date': '2022年11月10日(木)',
#   'prefecture': '神奈川県'}]

# %%
len(decks["others"])
# Out:
# 92
